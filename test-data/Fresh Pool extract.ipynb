# %%
import requests
from bs4 import BeautifulSoup

headers = {"User-Agent": "Mozilla/5.0"}

def get_product_links_from_page(url):
    res = requests.get(url, headers=headers)
    soup = BeautifulSoup(res.text, "html.parser")
    product_links = [a["href"].strip() for a in soup.select("a.product-item-link") if a.get("href")]
    return product_links

def scrape_product_details(product_url):
    res = requests.get(product_url, headers=headers)
    soup = BeautifulSoup(res.text, "html.parser")

    def get_text(selector):
        tag = soup.select_one(selector)
        return tag.get_text(strip=True) if tag else "N/A"

    title = get_text("h1.page-title span.base")
    overview = get_text("div.product.attribute.overview div.value")
    price = get_text("span.price")
    stock_tag = soup.select_one("div.product-info-stock-sku div.stock")
    stock = stock_tag.get_text(strip=True) if stock_tag else "N/A"
    description = get_text("div.product.attribute.description div.value")

    product_data = {
        "title": title,
        "overview": overview,
        "price": price,
        "stock": stock,
        "description": description,
        "link": product_url,
    }

    # More Information table
    rows = soup.select("table#product-attribute-specs-table tr")
    for row in rows:
        try:
            key = row.select_one("th").text.strip()
            value = row.select_one("td").text.strip()
            product_data[key] = value
        except:
            continue

    return product_data

# === MAIN SCRAPER ===
base_url = "https://www.freshpoolsupply.com/chemical/chlorine.html"
page = 1
all_product_links = []

while True:
    paged_url = f"{base_url}?p={page}"
    print(f"Scraping page {page} → {paged_url}")
    links = get_product_links_from_page(paged_url)
    if not links:
        print("No more products found. Ending pagination loop.")
        break
    all_product_links.extend(links)
    page += 1

print(f"\nTotal product links collected: {len(all_product_links)}")

# Scrape each product
all_products = []
for i, link in enumerate(all_product_links, 1):
    print(f"Scraping product {i}/{len(all_product_links)}: {link}")
    product_data = scrape_product_details(link)
    all_products.append(product_data)

# Preview first product (optional)
print("\n📦 Sample Product:\n", all_products[0])
# Out:
# Scraping page 1 → https://www.freshpoolsupply.com/chemical/chlorine.html?p=1
# Scraping page 2 → https://www.freshpoolsupply.com/chemical/chlorine.html?p=2
# Scraping page 3 → https://www.freshpoolsupply.com/chemical/chlorine.html?p=3
# Scraping page 4 → https://www.freshpoolsupply.com/chemical/chlorine.html?p=4
# Scraping page 5 → https://www.freshpoolsupply.com/chemical/chlorine.html?p=5
# Scraping page 6 → https://www.freshpoolsupply.com/chemical/chlorine.html?p=6
# Scraping page 7 → https://www.freshpoolsupply.com/chemical/chlorine.html?p=7
# Scraping page 8 → https://www.freshpoolsupply.com/chemical/chlorine.html?p=8
# No more products found. Ending pagination loop.
#
# Total product links collected: 73
# Scraping product 1/73: https://www.freshpoolsupply.com/chemical/chlorine/ab-3-tabs-50-lbalr.html
# Scraping product 2/73: https://www.freshpoolsupply.com/chemical/chlorine/ab-granular-dichlor-50-lbloq.html
# Scraping product 3/73: https://www.freshpoolsupply.com/chemical/chlorine/algaecure-25-lbrrm.html
# Scraping product 4/73: https://www.freshpoolsupply.com/chemical/chlorine/scent-trific-3-jumbo-tab-znn.html
# Scraping product 5/73: https://www.freshpoolsupply.com/chemical/chlorine/scent-trific-3-jumbo-tab-35lb-box-of-70ccq.html
# Scraping product 6/73: https://www.freshpoolsupply.com/chemical/chlorine/floating-chlorinatordjh.html
# Scraping product 7/73: https://www.freshpoolsupply.com/chemical/chlorine/frog-chlorinator-oxr.html
# Scraping product 8/73: https://www.freshpoolsupply.com/chemical/chlorine/shimmer-n-shock-dichlor-1-lbpyw.html
# Scraping product 9/73: https://www.freshpoolsupply.com/chemical/chlorine/shimmer-n-shock-dichlor-5-lbcqq.html
# Scraping product 10/73: https://www.freshpoolsupply.com/chemical/chlorine/shock-swim-15-1-lbvar.html
# Scraping product 11/73: https://www.freshpoolsupply.com/chemical/chlorine/shock-swim-15-1-lb-12pkcmz.html
# Scraping product 12/73: https://www.freshpoolsupply.com/chemical/chlorine/shock-swim-15-50-lbehc.html
# Scraping product 13/73: https://www.freshpoolsupply.com/chemical/chlorine/pl-clean-shock-1-lb-24pkfqw.html
# Scraping product 14/73: https://www.freshpoolsupply.com/chemical/chlorine/pl-instant-clear-cleaning-granules-35-lbixf.html
# Scraping product 15/73: https://www.freshpoolsupply.com/chemical/chlorine/pl-mpt-tabs-4lbzrf.html
# Scraping product 16/73: https://www.freshpoolsupply.com/chemical/chlorine/pl-non-chlorine-oxidizer-1-lb-24pkasm.html
# Scraping product 17/73: https://www.freshpoolsupply.com/chemical/chlorine/pl-rapid-shock-55x-1-lb-cnh.html
# Scraping product 18/73: https://www.freshpoolsupply.com/chemical/chlorine/pl-turboshock-1-lbhfy.html
# Scraping product 19/73: https://www.freshpoolsupply.com/chemical/chlorine/pl-turboshock-1-lb-12pkkcb.html
# Scraping product 20/73: https://www.freshpoolsupply.com/chemical/chlorine/shimmer-n-shock-dichlor-1-lbpyw.html
# Scraping product 21/73: https://www.freshpoolsupply.com/chemical/chlorine/shimmer-n-shock-dichlor-5-lbcqq.html
# Scraping product 22/73: https://www.freshpoolsupply.com/chemical/chlorine/shock-swim-15-1-lbvar.html
# Scraping product 23/73: https://www.freshpoolsupply.com/chemical/chlorine/shock-swim-15-1-lb-12pkcmz.html
# Scraping product 24/73: https://www.freshpoolsupply.com/chemical/chlorine/shock-swim-15-50-lbehc.html
# Scraping product 25/73: https://www.freshpoolsupply.com/chemical/chlorine/pl-turboshock-1-lb-12pkkcb.html
# Scraping product 26/73: https://www.freshpoolsupply.com/chemical/chlorine/pl-3-tabs-4-81lbzho.html
# Scraping product 27/73: https://www.freshpoolsupply.com/chemical/chlorine/pl-clean-shock-1-lb-12pkfhj.html
# Scraping product 28/73: https://www.freshpoolsupply.com/chemical/chlorine/pl-instant-clear-cleaning-granules-5-lbmay.html
# Scraping product 29/73: https://www.freshpoolsupply.com/chemical/chlorine/pl-mpt-tabs-21lboro.html
# Scraping product 30/73: https://www.freshpoolsupply.com/chemical/chlorine/pl-nst-prime-20-6lboay.html
# Scraping product 31/73: https://www.freshpoolsupply.com/chemical/chlorine/pl-non-chlorine-oxidizer-1-lbhgs.html
# Scraping product 32/73: https://www.freshpoolsupply.com/chemical/chlorine/pl-non-chlorine-oxidizer-1-lb-12pkfem.html
# Scraping product 33/73: https://www.freshpoolsupply.com/chemical/chlorine/pl-turboshock-17-lbedb.html
# Scraping product 34/73: https://www.freshpoolsupply.com/chemical/chlorine/pl-turboshock-25-lbdvn.html
# Scraping product 35/73: https://www.freshpoolsupply.com/chemical/chlorine/pl-turboshock-5-lbtiu.html
# Scraping product 36/73: https://www.freshpoolsupply.com/chemical/chlorine/shimmer-n-shock-dichlor-1-lb-12pkqbl.html
# Scraping product 37/73: https://www.freshpoolsupply.com/chemical/chlorine/shimmer-n-shock-dichlor-10-lbjpp.html
# Scraping product 38/73: https://www.freshpoolsupply.com/chemical/chlorine/shimmer-n-shock-dichlor-25-lbfyr.html
# Scraping product 39/73: https://www.freshpoolsupply.com/chemical/chlorine/shimmer-n-shock-dichlor-50-lbxnt.html
# Scraping product 40/73: https://www.freshpoolsupply.com/chemical/chlorine/solar-color-led-chlorinator-qai.html
# Scraping product 41/73: https://www.freshpoolsupply.com/chemical/chlorine/surfin-shark-spa-chlorinatoryvm.html
# Scraping product 42/73: https://www.freshpoolsupply.com/chemical/chlorine/derby-duck-spa-chlorinatormon.html
# Scraping product 43/73: https://www.freshpoolsupply.com/chemical/chlorine/scent-trific-3-jumbo-tabs-10-lbkca.html
# Scraping product 44/73: https://www.freshpoolsupply.com/chemical/chlorine/tab-floater-1-in-ppc.html
# Scraping product 45/73: https://www.freshpoolsupply.com/chemical/chlorine/white-mallard-chlorine-dispenserpav.html
# Scraping product 46/73: https://www.freshpoolsupply.com/chemical/chlorine/cch-endurance-25lb-tabswer.html
# Scraping product 47/73: https://www.freshpoolsupply.com/chemical/chlorine/chillin-charlie-chlorinatorslz.html
# Scraping product 48/73: https://www.freshpoolsupply.com/chemical/chlorine/clearview-tabs-25-lbajj.html
# Scraping product 49/73: https://www.freshpoolsupply.com/chemical/chlorine/clearview-tabs-50-lbsvg.html
# Scraping product 50/73: https://www.freshpoolsupply.com/chemical/chlorine/shimmer-n-shock-dichlor-1-lb-24pkcem.html
# Scraping product 51/73: https://www.freshpoolsupply.com/chemical/chlorine/shock-swim-15-1-lb-24pkaji.html
# Scraping product 52/73: https://www.freshpoolsupply.com/chemical/chlorine/solar-pineapple-chlorinatorkxr.html
# Scraping product 53/73: https://www.freshpoolsupply.com/chemical/chlorine/pl-1-tabs-5lbphj.html
# Scraping product 54/73: https://www.freshpoolsupply.com/chemical/chlorine/pl-active-cleaning-granules-100-lbhjn.html
# Scraping product 55/73: https://www.freshpoolsupply.com/chemical/chlorine/pl-back-to-blue-1-kitjqb.html
# Scraping product 56/73: https://www.freshpoolsupply.com/chemical/chlorine/pl-mpt-tabs-11lbuat.html
# Scraping product 57/73: https://www.freshpoolsupply.com/chemical/chlorine/pl-nst-prime-39-4lblvk.html
# Scraping product 58/73: https://www.freshpoolsupply.com/chemical/chlorine/pl-rapid-shock-1-lbmjh.html
# Scraping product 59/73: https://www.freshpoolsupply.com/chemical/chlorine/pl-rapid-shock-1-lb-12pkxgm.html
# Scraping product 60/73: https://www.freshpoolsupply.com/chemical/chlorine/pl-rapid-shock-1-lb-24pkcln.html
# Scraping product 61/73: https://www.freshpoolsupply.com/chemical/chlorine/pl-rapid-shock-5-lbdwd.html
# Scraping product 62/73: https://www.freshpoolsupply.com/chemical/chlorine/pl-turboshock-1-lb-24pkblm.html
# Scraping product 63/73: https://www.freshpoolsupply.com/chemical/chlorine/pl-turboshock-55x1-lbmls.html
# Scraping product 64/73: https://www.freshpoolsupply.com/chemical/chlorine/pl-turboshock-65-lbjmn.html
# Scraping product 65/73: https://www.freshpoolsupply.com/chemical/chlorine/pink-flamingo-chlorine-dispenserwnf.html
# Scraping product 66/73: https://www.freshpoolsupply.com/chemical/chlorine/mallard-chlorine-dispenseryfv.html
# Scraping product 67/73: https://www.freshpoolsupply.com/chemical/chlorine/nba-basketball-chlorine-dispenserymo.html
# Scraping product 68/73: https://www.freshpoolsupply.com/chemical/chlorine/nst-floatermco.html
# Scraping product 69/73: https://www.freshpoolsupply.com/chemical/chlorine/deluxe-tab-floateraqz.html
# Scraping product 70/73: https://www.freshpoolsupply.com/chemical/chlorine/ab-power-blast-70-100-lbcyp.html
# Scraping product 71/73: https://www.freshpoolsupply.com/chemical/chlorine/algaecure-2-lbwjh.html
# Scraping product 72/73: https://www.freshpoolsupply.com/chemical/chlorine/algaecure-50-lbofc.html
# Scraping product 73/73: https://www.freshpoolsupply.com/chemical/chlorine/trichlor-granular-ezchlor-50-lbxdm.html
#
# 📦 Sample Product:
#  {'title': 'AB 3" Tabs 50 lb | 40631A', 'overview': 'Applied Biochemists 3" Tablets', 'price': '$284.95', 'stock': 'Out of stock', 'description': 'Applied Biochemists® 3” TabletsSlow dissolving, 3” stabilized chlorinating tablets contain 90% available chlorine to effectively sanitize and maintain consistent chlorine levels.When using 3” Tablets, shock treat at least once a week using Applied Biochemists® Power Blast 70 GranularFor best results, add tablets to a new, clean skimmer, floater or automatic feederTest the chlorine and pH levels at least twice a week and adjust as needed', 'link': 'https://www.freshpoolsupply.com/chemical/chlorine/ab-3-tabs-50-lbalr.html', 'Manufacturer SKU': '40631A', 'Size': '50 lb', 'Brand': 'APPLIED BIO'}

# %%
all_products
# Out:
# [{'title': 'AB 3" Tabs 50 lb | 40631A',
#   'overview': 'Applied Biochemists 3" Tablets',
#   'price': '$284.95',
#   'stock': 'Out of stock',
#   'description': 'Applied Biochemists® 3” TabletsSlow dissolving, 3” stabilized chlorinating tablets contain 90% available chlorine to effectively sanitize and maintain consistent chlorine levels.When using 3” Tablets, shock treat at least once a week using Applied Biochemists® Power Blast 70 GranularFor best results, add tablets to a new, clean skimmer, floater or automatic feederTest the chlorine and pH levels at least twice a week and adjust as needed',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/ab-3-tabs-50-lbalr.html',
#   'Manufacturer SKU': '40631A',
#   'Size': '50 lb',
#   'Brand': 'APPLIED BIO'},
#  {'title': 'AB Granular Dichlor 50 lb | 40697A',
#   'overview': 'Applied Biochemists Granular Chlorine',
#   'price': '$356.95',
#   'stock': 'Out of stock',
#   'description': 'Applied Biochemists® Granular ChlorineThis stabilized and concentrated formula contains 56% available chlorine. When used as directed, it effectively controls bacteria and algae.Compatible with chlorine systems',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/ab-granular-dichlor-50-lbloq.html',
#   'Manufacturer SKU': '40697A',
#   'Size': '50 lb',
#   'Brand': 'APPLIED BIO'},
#  {'title': 'Algaecure 25 lb | CVTC025',
#   'overview': 'ClearView Algaecure Pail, 25 Lb',
#   'price': '$206.95',
#   'stock': 'Out of stock',
#   'description': 'AlgaecurePart: CVTC025Algaecure can be used as a super chlorinator and effective algaecide for black algae in white plaster pools, leaving safe, sanitary, sparkling water.Description•\tActive Ingredient: 99% Trichlor•\tCan be used as a super chlorinator•\tEffective algaecide/algaecides for black algae in white plaster pools•\tEnsures safe, sanitary, sparkling clean water',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/algaecure-25-lbrrm.html',
#   'Manufacturer SKU': 'CVTC025',
#   'Size': '25 lb',
#   'Brand': 'OREQ'},
#  {'title': 'Scent-Trific 3" Jumbo Tab  | CVTLSTCR',
#   'overview': 'ClearView Scent-Trific Tabs Full Strength, Low Odor Chlorine Tabs Features: – 99% premium grade Trichlor – World’s first low odor chlorine in a floral fresh scent package – Individually wrapped 8  Oz. tab – No gummy binders Benefits: – Reduced store odor – No film or clogging of skimmers, chlorinators or filters – Ensures safe, sanitary, sparkling water',
#   'price': '$5.95',
#   'stock': 'In stock',
#   'description': 'Scent-Trific Jumbo Tabs 3Scent-Trific Chlorine Plus Tabs are an advanced, low odor, full strength, chlorine technology. No other tab delivers more!Description•\tWorlds first low odor chlorine in a floral fresh scent package•\tFull Strength•\tLow Odor•\t99% premium grade Trichlor•\tNo gummy binders•\tReduced store odor•\tNo film or clogging of skimmers, chlorinators, or filters•\tEnsures safe, sanitary, sparkling water•\tSanitizer / Sanitizers',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/scent-trific-3-jumbo-tab-znn.html',
#   'Manufacturer SKU': 'CVTLSTCR',
#   'Size': '8  Oz',
#   'Brand': 'OREQ'},
#  {'title': 'Scent-Trific 3" Jumbo Tab 35lb Box of 70 | CVTLSTCR035',
#   'overview': 'ClearView Scent-Trific Tabs Full Strength, Low Odor Chlorine Tabs Features: – 99% premium grade Trichlor – World’s first low odor chlorine in a floral fresh scent package – Individually wrapped 8  Oz. tab – No gummy binders Benefits: – Reduced store odor – No film or clogging of skimmers, chlorinators or filters – Ensures safe, sanitary, sparkling water',
#   'price': '$359.95',
#   'stock': 'Out of stock',
#   'description': 'Scent-Trific Jumbo Tabs 3Scent-Trific Chlorine Plus Tabs are an advanced, low odor, full strength, chlorine technology. No other tab delivers more!Description•\tWorlds first low odor chlorine in a floral fresh scent package•\tFull Strength•\tLow Odor•\t99% premium grade Trichlor•\tNo gummy binders•\tReduced store odor•\tNo film or clogging of skimmers, chlorinators, or filters•\tEnsures safe, sanitary, sparkling water•\tSanitizer / Sanitizers',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/scent-trific-3-jumbo-tab-35lb-box-of-70ccq.html',
#   'Manufacturer SKU': 'CVTLSTCR035',
#   'Size': '8  Oz',
#   'Brand': 'OREQ'},
#  {'title': 'Floating Chlorinator | 58470-110-690',
#   'overview': 'Floating Chemical Dispenser For 3In Tablets',
#   'price': '$15.95',
#   'stock': 'In stock',
#   'description': 'N/A',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/floating-chlorinatordjh.html',
#   'Manufacturer SKU': '58470-110-690',
#   'Brand': 'CMP'},
#  {'title': 'Frog Chlorinator  | 8710',
#   'overview': 'Frog Chlorinator',
#   'price': '$12.95',
#   'stock': 'In stock',
#   'description': 'N/A',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/frog-chlorinator-oxr.html',
#   'Manufacturer SKU': '8710',
#   'Brand': 'SWIMLINE'},
#  {'title': "Shimmer N' Shock DiChlor 1 lb | CVDB001",
#   'overview': 'ClearView Shimmer n Shock Di-Chlor Granular Shock 1lb',
#   'price': '$9.95',
#   'stock': 'Out of stock',
#   'description': "Shimmer-N' ShockPart: Multiple - CVDB001Chlorine-based shock treatment to control bacteria and algae.Description•\tActive Ingredient: 99% Sodium Dichlor•\tNo pre-dissolving•\tCompletely soluble•\tNo residue•\tWill not cause pH bounce•\tEconomical shock treatment•\tRestores sparkle and clarity to dull water•\tPerfect for vinyl-lined or above ground pools•\tShock/shocks",
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/shimmer-n-shock-dichlor-1-lbpyw.html',
#   'Manufacturer SKU': 'CVDB001',
#   'Size': '1 lb',
#   'Brand': 'OREQ'},
#  {'title': "Shimmer N' Shock DiChlor 5 lb | CVDB005",
#   'overview': 'ClearView Shimmer n Shock Di-Chlor Granular Shock 5Lb',
#   'price': '$41.95',
#   'stock': 'Out of stock',
#   'description': "Shimmer-N' ShockPart: Multiple - CVDB005Chlorine-based shock treatment to control bacteria and algae.Description•\tActive Ingredient: 99% Sodium Dichlor•\tNo pre-dissolving•\tCompletely soluble•\tNo residue•\tWill not cause pH bounce•\tEconomical shock treatment•\tRestores sparkle and clarity to dull water•\tPerfect for vinyl-lined or above ground pools•\tShock/shocks",
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/shimmer-n-shock-dichlor-5-lbcqq.html',
#   'Manufacturer SKU': 'CVDB005',
#   'Size': '5 lb',
#   'Brand': 'OREQ'},
#  {'title': 'Shock & Swim 15 1 lb | CVCF001',
#   'overview': 'ClearView Shock & Swim 15, Chlorine Free Shock, 1lb',
#   'price': '$5.95',
#   'stock': 'Out of stock',
#   'description': 'Chlor Free Shock & Swim 15Part: CVCF001Multiple - See DescriptionNon-chlorine shock oxidizer removes organic contaminants and improves water clarity.Description•\tActive Ingredient: 45% Potassium Monopersulfate•\tRemoves chloramines•\tSafe with Chlorine, Bromine, and copper/silver sanitizer systems•\tWill not raise Chlorine to unsafe levels•\tRe-enter pool as quickly as 15 minutes after application•\tRestores sparkle and clarity to dull water•\tWill not bleach or fade vinyl liners•\tShock/shocks',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/shock-swim-15-1-lbvar.html',
#   'Manufacturer SKU': 'CVCF001',
#   'Size': '1 lb',
#   'Brand': 'OREQ'},
#  {'title': 'Shock & Swim 15 1 lb 12pk | CVCF001PK12',
#   'overview': 'Shock & Swim 15 1 lb 12pk',
#   'price': '$59.95',
#   'stock': 'Out of stock',
#   'description': 'Chlor Free Shock & Swim 15Part: CVCF001PK12Non-chlorine shock oxidizer removes organic contaminants and improves water clarity.Description•\tActive Ingredient: 45% Potassium Monopersulfate•\tRemoves chloramines•\tSafe with Chlorine, Bromine, and copper/silver sanitizer systems•\tWill not raise Chlorine to unsafe levels•\tRe-enter pool as quickly as 15 minutes after application•\tRestores sparkle and clarity to dull water•\tWill not bleach or fade vinyl liners•\tShock/shocks',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/shock-swim-15-1-lb-12pkcmz.html',
#   'Manufacturer SKU': 'CVCF001PK12',
#   'Size': '12 lb',
#   'Brand': 'OREQ'},
#  {'title': 'Shock & Swim 15 50 lb | CVCF050',
#   'overview': 'ClearView Shock & Swim 15, Chlorine Free Shock, 50lb',
#   'price': '$220.95',
#   'stock': 'In stock',
#   'description': 'Chlor Free Shock & Swim 15Part: CVCF050Non-chlorine shock oxidizer removes organic contaminants and improves water clarity.Description•\tActive Ingredient: 45% Potassium Monopersulfate•\tRemoves chloramines•\tSafe with Chlorine, Bromine, and copper/silver sanitizer systems•\tWill not raise Chlorine to unsafe levels•\tRe-enter pool as quickly as 15 minutes after application•\tRestores sparkle and clarity to dull water•\tWill not bleach or fade vinyl liners•\tShock/shocks',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/shock-swim-15-50-lbehc.html',
#   'Manufacturer SKU': 'CVCF050',
#   'Size': '50 lb',
#   'Brand': 'OREQ'},
#  {'title': 'PL Clean Shock 1 lb 24pk | 52401PK24',
#   'overview': 'Poolife Clean Shock 1 lb 24pk',
#   'price': '$195.95',
#   'stock': 'Out of stock',
#   'description': 'N/A',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/pl-clean-shock-1-lb-24pkfqw.html',
#   'Manufacturer SKU': '52401PK24',
#   'Size': '24 lb',
#   'Brand': 'POOLIFE'},
#  {'title': 'PL Instant Clear Cleaning Granules 35 lb | 32101',
#   'overview': 'Poolife Instant Clear Cleaning Granules',
#   'price': '$215.95',
#   'stock': 'Out of stock',
#   'description': 'N/A',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/pl-instant-clear-cleaning-granules-35-lbixf.html',
#   'Manufacturer SKU': '32101',
#   'Size': '35 lb',
#   'Brand': 'POOLIFE'},
#  {'title': 'PL MPT Tabs 4lb | 42120',
#   'overview': 'Poolife MPT Extra',
#   'price': '$50.95',
#   'stock': 'Out of stock',
#   'description': 'N/A',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/pl-mpt-tabs-4lbzrf.html',
#   'Manufacturer SKU': '42120',
#   'Size': '4 lb',
#   'Brand': 'POOLIFE'},
#  {'title': 'PL Non Chlorine Oxidizer 1 lb 24pk | 22102PK24',
#   'overview': 'Poolife Non Chlorine Oxidizer 1 lb 24pk',
#   'price': '$186.95',
#   'stock': 'Out of stock',
#   'description': 'N/A',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/pl-non-chlorine-oxidizer-1-lb-24pkasm.html',
#   'Manufacturer SKU': '22102PK24',
#   'Size': '24 lb',
#   'Brand': 'POOLIFE'},
#  {'title': 'PL Rapid Shock [55x 1 lb] | 22250',
#   'overview': 'Poolife Rapid Shock [55x 1 lb]',
#   'price': '$284.95',
#   'stock': 'Out of stock',
#   'description': 'Poolife™ Rapid Shock™ Shock TreatmentQuickly brings chlorine levels into balance after heavy pool usage and after rain or windstorms. It works fast to rid the pool water of contaminants and keep it ready for a refreshing, clean swim.•\tAfter a good pool party—or a good rain or windstorm—contaminants can build up in your pool water•\tPoolife™ Rapid Shock works fast to clear contaminants, so your pool water is ready for your next clean, refreshing swim•\tCal Hypo formula quickly brings chlorine levels into balance without adding additional cyanuric acid (CYA)•\tUse Poolife™ Rapid Shock to shock treat your pool water once a week—no need to pre-mix•\tFor best results, test and balance your pool water then follow the easy step-by-step, on-pack instructions to shock treat•\tActive ingredient: 68% Calcium Hypochlorite (Cal Hypo)',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/pl-rapid-shock-55x-1-lb-cnh.html',
#   'Manufacturer SKU': '22250',
#   'Size': '55 lb',
#   'Brand': 'POOLIFE'},
#  {'title': 'PL TurboShock 1 lb | 22405',
#   'overview': 'Poolife Turbo Shock Shock Treatment',
#   'price': '$8.95',
#   'stock': 'In stock',
#   'description': 'Poolife™ TurboShock™ Shock Treatment: Cal Hypo ShockSKUs: 22405, 22406, 22403, 22402, 62082 & 22404The strongest Cal Hypo shock product in the industry! Dissolves quickly and completely to combat algae and bacteria and keep pool water sparkling clean and clear with less work.•\tQuickly and easily combat algae and bacteria with the strongest Cal Hypo shock in the industry•\tStep 2 of the 3-step Poolife™ MPT Extra™ System, Poolife™ TurboShock keeps pool water clean and crystal clear•\tQuick-dissolving cal hypo shock, great for all pool surfaces•\tUse Poolife™ TurboShock to shock treat pool water once a week — no need to pre-dissolve Poolife’s cal hypo shock•\tFor best results, test and balance your pool water then follow the easy step-by-step, on-pack instructions to shock treat with Poolife cal hypo shock•\tActive ingredient: 78% Calcium Hypochlorite (Cal Hypo)',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/pl-turboshock-1-lbhfy.html',
#   'Manufacturer SKU': '22405',
#   'Size': '1 lb',
#   'Brand': 'POOLIFE'},
#  {'title': 'PL TurboShock 1 lb 12pk | 22405PK12',
#   'overview': 'Poolife TurboShock 1 lb 12pk',
#   'price': '$85.95',
#   'stock': 'In stock',
#   'description': 'Poolife™ TurboShock™ Shock Treatment: Cal Hypo ShockSKUs: 22405, 22406, 22403, 22402, 62082 & 22404The strongest Cal Hypo shock product in the industry! Dissolves quickly and completely to combat algae and bacteria and keep pool water sparkling clean and clear with less work.•\tQuickly and easily combat algae and bacteria with the strongest Cal Hypo shock in the industry•\tStep 2 of the 3-step Poolife™ MPT Extra™ System, Poolife™ TurboShock keeps pool water clean and crystal clear•\tQuick-dissolving cal hypo shock, great for all pool surfaces•\tUse Poolife™ TurboShock to shock treat pool water once a week — no need to pre-dissolve Poolife’s cal hypo shock•\tFor best results, test and balance your pool water then follow the easy step-by-step, on-pack instructions to shock treat with Poolife cal hypo shock•\tActive ingredient: 78% Calcium Hypochlorite (Cal Hypo)',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/pl-turboshock-1-lb-12pkkcb.html',
#   'Manufacturer SKU': '22405PK12',
#   'Size': '12 lb',
#   'Brand': 'POOLIFE'},
#  {'title': "Shimmer N' Shock DiChlor 1 lb | CVDB001",
#   'overview': 'ClearView Shimmer n Shock Di-Chlor Granular Shock 1lb',
#   'price': '$9.95',
#   'stock': 'Out of stock',
#   'description': "Shimmer-N' ShockPart: Multiple - CVDB001Chlorine-based shock treatment to control bacteria and algae.Description•\tActive Ingredient: 99% Sodium Dichlor•\tNo pre-dissolving•\tCompletely soluble•\tNo residue•\tWill not cause pH bounce•\tEconomical shock treatment•\tRestores sparkle and clarity to dull water•\tPerfect for vinyl-lined or above ground pools•\tShock/shocks",
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/shimmer-n-shock-dichlor-1-lbpyw.html',
#   'Manufacturer SKU': 'CVDB001',
#   'Size': '1 lb',
#   'Brand': 'OREQ'},
#  {'title': "Shimmer N' Shock DiChlor 5 lb | CVDB005",
#   'overview': 'ClearView Shimmer n Shock Di-Chlor Granular Shock 5Lb',
#   'price': '$41.95',
#   'stock': 'Out of stock',
#   'description': "Shimmer-N' ShockPart: Multiple - CVDB005Chlorine-based shock treatment to control bacteria and algae.Description•\tActive Ingredient: 99% Sodium Dichlor•\tNo pre-dissolving•\tCompletely soluble•\tNo residue•\tWill not cause pH bounce•\tEconomical shock treatment•\tRestores sparkle and clarity to dull water•\tPerfect for vinyl-lined or above ground pools•\tShock/shocks",
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/shimmer-n-shock-dichlor-5-lbcqq.html',
#   'Manufacturer SKU': 'CVDB005',
#   'Size': '5 lb',
#   'Brand': 'OREQ'},
#  {'title': 'Shock & Swim 15 1 lb | CVCF001',
#   'overview': 'ClearView Shock & Swim 15, Chlorine Free Shock, 1lb',
#   'price': '$5.95',
#   'stock': 'Out of stock',
#   'description': 'Chlor Free Shock & Swim 15Part: CVCF001Multiple - See DescriptionNon-chlorine shock oxidizer removes organic contaminants and improves water clarity.Description•\tActive Ingredient: 45% Potassium Monopersulfate•\tRemoves chloramines•\tSafe with Chlorine, Bromine, and copper/silver sanitizer systems•\tWill not raise Chlorine to unsafe levels•\tRe-enter pool as quickly as 15 minutes after application•\tRestores sparkle and clarity to dull water•\tWill not bleach or fade vinyl liners•\tShock/shocks',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/shock-swim-15-1-lbvar.html',
#   'Manufacturer SKU': 'CVCF001',
#   'Size': '1 lb',
#   'Brand': 'OREQ'},
#  {'title': 'Shock & Swim 15 1 lb 12pk | CVCF001PK12',
#   'overview': 'Shock & Swim 15 1 lb 12pk',
#   'price': '$59.95',
#   'stock': 'Out of stock',
#   'description': 'Chlor Free Shock & Swim 15Part: CVCF001PK12Non-chlorine shock oxidizer removes organic contaminants and improves water clarity.Description•\tActive Ingredient: 45% Potassium Monopersulfate•\tRemoves chloramines•\tSafe with Chlorine, Bromine, and copper/silver sanitizer systems•\tWill not raise Chlorine to unsafe levels•\tRe-enter pool as quickly as 15 minutes after application•\tRestores sparkle and clarity to dull water•\tWill not bleach or fade vinyl liners•\tShock/shocks',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/shock-swim-15-1-lb-12pkcmz.html',
#   'Manufacturer SKU': 'CVCF001PK12',
#   'Size': '12 lb',
#   'Brand': 'OREQ'},
#  {'title': 'Shock & Swim 15 50 lb | CVCF050',
#   'overview': 'ClearView Shock & Swim 15, Chlorine Free Shock, 50lb',
#   'price': '$220.95',
#   'stock': 'In stock',
#   'description': 'Chlor Free Shock & Swim 15Part: CVCF050Non-chlorine shock oxidizer removes organic contaminants and improves water clarity.Description•\tActive Ingredient: 45% Potassium Monopersulfate•\tRemoves chloramines•\tSafe with Chlorine, Bromine, and copper/silver sanitizer systems•\tWill not raise Chlorine to unsafe levels•\tRe-enter pool as quickly as 15 minutes after application•\tRestores sparkle and clarity to dull water•\tWill not bleach or fade vinyl liners•\tShock/shocks',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/shock-swim-15-50-lbehc.html',
#   'Manufacturer SKU': 'CVCF050',
#   'Size': '50 lb',
#   'Brand': 'OREQ'},
#  {'title': 'PL TurboShock 1 lb 12pk | 22405PK12',
#   'overview': 'Poolife TurboShock 1 lb 12pk',
#   'price': '$85.95',
#   'stock': 'In stock',
#   'description': 'Poolife™ TurboShock™ Shock Treatment: Cal Hypo ShockSKUs: 22405, 22406, 22403, 22402, 62082 & 22404The strongest Cal Hypo shock product in the industry! Dissolves quickly and completely to combat algae and bacteria and keep pool water sparkling clean and clear with less work.•\tQuickly and easily combat algae and bacteria with the strongest Cal Hypo shock in the industry•\tStep 2 of the 3-step Poolife™ MPT Extra™ System, Poolife™ TurboShock keeps pool water clean and crystal clear•\tQuick-dissolving cal hypo shock, great for all pool surfaces•\tUse Poolife™ TurboShock to shock treat pool water once a week — no need to pre-dissolve Poolife’s cal hypo shock•\tFor best results, test and balance your pool water then follow the easy step-by-step, on-pack instructions to shock treat with Poolife cal hypo shock•\tActive ingredient: 78% Calcium Hypochlorite (Cal Hypo)',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/pl-turboshock-1-lb-12pkkcb.html',
#   'Manufacturer SKU': '22405PK12',
#   'Size': '12 lb',
#   'Brand': 'POOLIFE'},
#  {'title': 'PL 3" Tabs 4.81lb | 42107',
#   'overview': 'Poolife 3" Cleaning Tablets',
#   'price': '$42.95',
#   'stock': 'Out of stock',
#   'description': 'N/A',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/pl-3-tabs-4-81lbzho.html',
#   'Manufacturer SKU': '42107',
#   'Size': '4.81 lb',
#   'Brand': 'POOLIFE'},
#  {'title': 'PL Clean Shock 1 lb 12pk | 52401PK12',
#   'overview': 'Poolife Clean Shock 1 lb 12pk',
#   'price': '$97.95',
#   'stock': 'Out of stock',
#   'description': 'N/A',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/pl-clean-shock-1-lb-12pkfhj.html',
#   'Manufacturer SKU': '52401PK12',
#   'Size': '12 lb',
#   'Brand': 'POOLIFE'},
#  {'title': 'PL Instant Clear Cleaning Granules 5 lb | 32102',
#   'overview': 'Poolife Instant Clear Cleaning Granules',
#   'price': '$38.95',
#   'stock': 'In stock',
#   'description': 'N/A',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/pl-instant-clear-cleaning-granules-5-lbmay.html',
#   'Manufacturer SKU': '32102',
#   'Size': '5 lb',
#   'Brand': 'POOLIFE'},
#  {'title': 'PL MPT Tabs 21lb | 42122',
#   'overview': 'Poolife MPT Extra',
#   'price': '$159.95',
#   'stock': 'Out of stock',
#   'description': 'N/A',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/pl-mpt-tabs-21lboro.html',
#   'Manufacturer SKU': '42122',
#   'Size': '21 lb',
#   'Brand': 'POOLIFE'},
#  {'title': 'PL NST Prime 20.6lb | 22425',
#   'overview': 'Poolife NST Prime 70% Cal-Hypo Tablet, 20.6lb.',
#   'price': '$152.95',
#   'stock': 'In stock',
#   'description': 'N/A',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/pl-nst-prime-20-6lboay.html',
#   'Manufacturer SKU': '22425',
#   'Size': '20.6 lb',
#   'Brand': 'POOLIFE'},
#  {'title': 'PL Non Chlorine Oxidizer 1 lb | 22102',
#   'overview': 'Poolife Non Chlorine Oxidizer',
#   'price': '$7.95',
#   'stock': 'In stock',
#   'description': 'N/A',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/pl-non-chlorine-oxidizer-1-lbhgs.html',
#   'Manufacturer SKU': '22102',
#   'Size': '1 lb',
#   'Brand': 'POOLIFE'},
#  {'title': 'PL Non Chlorine Oxidizer 1 lb 12pk | 22102PK12',
#   'overview': 'Poolife Non Chlorine Oxidizer 1 lb 12pk',
#   'price': '$93.95',
#   'stock': 'Out of stock',
#   'description': 'N/A',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/pl-non-chlorine-oxidizer-1-lb-12pkfem.html',
#   'Manufacturer SKU': '22102PK12',
#   'Size': '12 lb',
#   'Brand': 'POOLIFE'},
#  {'title': 'PL TurboShock 17 lb | 22402',
#   'overview': 'Poolife Turbo Shock Shock Treatment',
#   'price': '$128.95',
#   'stock': 'Out of stock',
#   'description': 'Poolife™ TurboShock™ Shock Treatment: Cal Hypo ShockSKUs: 22405, 22406, 22403, 22402, 62082 & 22404The strongest Cal Hypo shock product in the industry! Dissolves quickly and completely to combat algae and bacteria and keep pool water sparkling clean and clear with less work.•\tQuickly and easily combat algae and bacteria with the strongest Cal Hypo shock in the industry•\tStep 2 of the 3-step Poolife™ MPT Extra™ System, Poolife™ TurboShock keeps pool water clean and crystal clear•\tQuick-dissolving cal hypo shock, great for all pool surfaces•\tUse Poolife™ TurboShock to shock treat pool water once a week — no need to pre-dissolve Poolife’s cal hypo shock•\tFor best results, test and balance your pool water then follow the easy step-by-step, on-pack instructions to shock treat with Poolife cal hypo shock•\tActive ingredient: 78% Calcium Hypochlorite (Cal Hypo)',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/pl-turboshock-17-lbedb.html',
#   'Manufacturer SKU': '22402',
#   'Size': '17 lb',
#   'Brand': 'POOLIFE'},
#  {'title': 'PL TurboShock 25 lb | 62082',
#   'overview': 'Poolife Turbo Shock Shock Treatment',
#   'price': '$166.95',
#   'stock': 'In stock',
#   'description': 'Poolife™ TurboShock™ Shock Treatment: Cal Hypo ShockSKUs: 22405, 22406, 22403, 22402, 62082 & 22404The strongest Cal Hypo shock product in the industry! Dissolves quickly and completely to combat algae and bacteria and keep pool water sparkling clean and clear with less work.•\tQuickly and easily combat algae and bacteria with the strongest Cal Hypo shock in the industry•\tStep 2 of the 3-step Poolife™ MPT Extra™ System, Poolife™ TurboShock keeps pool water clean and crystal clear•\tQuick-dissolving cal hypo shock, great for all pool surfaces•\tUse Poolife™ TurboShock to shock treat pool water once a week — no need to pre-dissolve Poolife’s cal hypo shock•\tFor best results, test and balance your pool water then follow the easy step-by-step, on-pack instructions to shock treat with Poolife cal hypo shock•\tActive ingredient: 78% Calcium Hypochlorite (Cal Hypo)',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/pl-turboshock-25-lbdvn.html',
#   'Manufacturer SKU': '62082',
#   'Size': '25 lb',
#   'Brand': 'POOLIFE'},
#  {'title': 'PL TurboShock 5 lb | 22403',
#   'overview': 'Poolife Turbo Shock Shock Treatment',
#   'price': '$43.95',
#   'stock': 'In stock',
#   'description': 'Poolife™ TurboShock™ Shock Treatment: Cal Hypo ShockSKUs: 22405, 22406, 22403, 22402, 62082 & 22404The strongest Cal Hypo shock product in the industry! Dissolves quickly and completely to combat algae and bacteria and keep pool water sparkling clean and clear with less work.•\tQuickly and easily combat algae and bacteria with the strongest Cal Hypo shock in the industry•\tStep 2 of the 3-step Poolife™ MPT Extra™ System, Poolife™ TurboShock keeps pool water clean and crystal clear•\tQuick-dissolving cal hypo shock, great for all pool surfaces•\tUse Poolife™ TurboShock to shock treat pool water once a week — no need to pre-dissolve Poolife’s cal hypo shock•\tFor best results, test and balance your pool water then follow the easy step-by-step, on-pack instructions to shock treat with Poolife cal hypo shock•\tActive ingredient: 78% Calcium Hypochlorite (Cal Hypo)',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/pl-turboshock-5-lbtiu.html',
#   'Manufacturer SKU': '22403',
#   'Size': '5 lb',
#   'Brand': 'POOLIFE'},
#  {'title': "Shimmer N' Shock DiChlor 1 lb 12pk | CVDB001PK12",
#   'overview': 'Shimmer n Shock Dc 1 lb 12pk',
#   'price': '$98.95',
#   'stock': 'Out of stock',
#   'description': "Shimmer-N' ShockPart: Multiple - CVDB001PK12Chlorine-based shock treatment to control bacteria and algae.Description•\tActive Ingredient: 99% Sodium Dichlor•\tNo pre-dissolving•\tCompletely soluble•\tNo residue•\tWill not cause pH bounce•\tEconomical shock treatment•\tRestores sparkle and clarity to dull water•\tPerfect for vinyl-lined or above ground pools•\tShock/shocks",
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/shimmer-n-shock-dichlor-1-lb-12pkqbl.html',
#   'Manufacturer SKU': 'CVDB001PK12',
#   'Size': '12 lb',
#   'Brand': 'OREQ'},
#  {'title': "Shimmer N' Shock DiChlor 10 lb | CVDB010",
#   'overview': 'ClearView Shimmer n Shock Di-Chlor Granular Shock 10lb',
#   'price': '$77.95',
#   'stock': 'Out of stock',
#   'description': "Shimmer-N' ShockPart: Multiple - CVDB010Chlorine-based shock treatment to control bacteria and algae.Description•\tActive Ingredient: 99% Sodium Dichlor•\tNo pre-dissolving•\tCompletely soluble•\tNo residue•\tWill not cause pH bounce•\tEconomical shock treatment•\tRestores sparkle and clarity to dull water•\tPerfect for vinyl-lined or above ground pools•\tShock/shocks",
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/shimmer-n-shock-dichlor-10-lbjpp.html',
#   'Manufacturer SKU': 'CVDB010',
#   'Size': '10 lb',
#   'Brand': 'OREQ'},
#  {'title': "Shimmer N' Shock DiChlor 25 lb | CVDB025",
#   'overview': 'ClearView Shimmer n Shock Di-Chlor Granular Shock 25lb',
#   'price': '$171.95',
#   'stock': 'Out of stock',
#   'description': "Shimmer-N' ShockPart: Multiple - CVDB025Chlorine-based shock treatment to control bacteria and algae.Description•\tActive Ingredient: 99% Sodium Dichlor•\tNo pre-dissolving•\tCompletely soluble•\tNo residue•\tWill not cause pH bounce•\tEconomical shock treatment•\tRestores sparkle and clarity to dull water•\tPerfect for vinyl-lined or above ground pools•\tShock/shocks",
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/shimmer-n-shock-dichlor-25-lbfyr.html',
#   'Manufacturer SKU': 'CVDB025',
#   'Size': '25 lb',
#   'Brand': 'OREQ'},
#  {'title': "Shimmer N' Shock DiChlor 50 lb | CVDB050",
#   'overview': 'ClearView Shimmer n Shock Di-Chlor Granular Shock 50lb',
#   'price': '$276.95',
#   'stock': 'Out of stock',
#   'description': "Shimmer-N' ShockPart: Multiple - CVDB050Chlorine-based shock treatment to control bacteria and algae.Description•\tActive Ingredient: 99% Sodium Dichlor•\tNo pre-dissolving•\tCompletely soluble•\tNo residue•\tWill not cause pH bounce•\tEconomical shock treatment•\tRestores sparkle and clarity to dull water•\tPerfect for vinyl-lined or above ground pools•\tShock/shocks",
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/shimmer-n-shock-dichlor-50-lbxnt.html',
#   'Manufacturer SKU': 'CVDB050',
#   'Size': '50 lb',
#   'Brand': 'OREQ'},
#  {'title': 'Solar Color LED Chlorinator  | 87290',
#   'overview': 'Solar Color LED Chlorinator',
#   'price': '$32.95',
#   'stock': 'In stock',
#   'description': 'N/A',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/solar-color-led-chlorinator-qai.html',
#   'Manufacturer SKU': '87290',
#   'Brand': 'SWIMLINE'},
#  {'title': 'Surfin Shark Spa Chlorinator | 11202',
#   'overview': 'Surfin Shark Spa Chlorinator',
#   'price': '$19.95',
#   'stock': 'In stock',
#   'description': 'N/A',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/surfin-shark-spa-chlorinatoryvm.html',
#   'Manufacturer SKU': '11202',
#   'Brand': 'GAME'},
#  {'title': 'Derby Duck Spa Chlorinator | 8000',
#   'overview': 'Derby Duck Spa Chemical Dispenser',
#   'price': '$19.95',
#   'stock': 'In stock',
#   'description': 'N/A',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/derby-duck-spa-chlorinatormon.html',
#   'Manufacturer SKU': '8000',
#   'Brand': 'A&B BRUSH'},
#  {'title': 'Scent-Trific 3" Jumbo Tabs 10 lb | CVTLST010',
#   'overview': 'ClearView Scent-TrificTM Tabs Full Strength, Low Odor Chlorine Tabs Features: – 99% premium grade Trichlor – World’s first low odor chlorine in a floral fresh scent package – Individually wrapped 8  Oz. tab – No gummy binders Benefits: – Reduced store odor – No film or clogging of skimmers, chlorinators or filters – Ensures safe, sanitary, sparkling water',
#   'price': '$79.95',
#   'stock': 'In stock',
#   'description': 'Scent-Trific Jumbo Tabs 3Part: CVTLST010Scent-Trific Chlorine Plus Tabs are an advanced, low odor, full strength, chlorine technology. No other tab delivers more!Description•\tWorlds first low odor chlorine in a floral fresh scent package•\tFull Strength•\tLow Odor•\t99% premium grade Trichlor•\tNo gummy binders•\tReduced store odor•\tNo film or clogging of skimmers, chlorinators, or filters•\tEnsures safe, sanitary, sparkling water•\tSanitizer / Sanitizers',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/scent-trific-3-jumbo-tabs-10-lbkca.html',
#   'Manufacturer SKU': 'CVTLST010',
#   'Size': '10 lb',
#   'Brand': 'OREQ'},
#  {'title': 'Tab Floater 1 In  | CL270',
#   'overview': 'Tab Floater Chlorinator 1"',
#   'price': '$5.95',
#   'stock': 'Out of stock',
#   'description': 'POP-UP Brominator / ChlorinatorPart: CL270POP-UP Spa Brominator/Chlorinator. Expands to size for easy storage, taking up only 4 3/4" x 2 5/8\' on the shelf.Description•\tPOP-UP Spa Brominator/Chlorinator•\tFor 1" Tabs•\tOpens to 4.75" W x 4.62" H•\tColor: Blue & white',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/tab-floater-1-in-ppc.html',
#   'Manufacturer SKU': 'CL270',
#   'Brand': 'OREQ'},
#  {'title': 'White Mallard Chlorine Dispenser | 32131',
#   'overview': 'White Mallard Chlorine Dispenser',
#   'price': '$33.95',
#   'stock': 'In stock',
#   'description': 'N/A',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/white-mallard-chlorine-dispenserpav.html',
#   'Manufacturer SKU': '32131',
#   'Brand': 'POOLMASTER'},
#  {'title': 'CCH Endurance 25lb Tabs | 23227',
#   'overview': 'CC Endurance 25lb Tabs',
#   'price': '$96.95',
#   'stock': 'Out of stock',
#   'description': 'N/A',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/cch-endurance-25lb-tabswer.html',
#   'Manufacturer SKU': '23227',
#   'Size': '25 lb',
#   'Brand': 'CCH'},
#  {'title': 'Chillin Charlie Chlorinator | CL380',
#   'overview': 'Chillin Charlie Floating Chlorinator',
#   'price': '$36.95',
#   'stock': 'In stock',
#   'description': "Chillin' Charlie ChlorinatorPart: CL380*** New Design ***Chill out with the cool dude at the pool! Chillin' Charlie floats on his own iceberg while chlorine is distributed throughout the pool.Description•\t3”-tab chlorinators•\t4 lb. capacity•\tCute penguin design to add an element of fun to your pool•\tIntegrated color throughout both the top of the iceberg and base•\tPop-up, locking base for less storage space•\tAdjustable flow control base.  Simply twist the bottom cuff to expose as many open slats as you'd like to allow for the appropriate amount of flow and chemical release.",
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/chillin-charlie-chlorinatorslz.html',
#   'Manufacturer SKU': 'CL380',
#   'Brand': 'OREQ'},
#  {'title': 'ClearView Tabs 25 lb | CVTL025U',
#   'overview': 'ClearView 3" Jumbo Tab Unwrapped Pail, 25 Lb',
#   'price': '$135.95',
#   'stock': 'In stock',
#   'description': 'Jumbo Tabs 3"Part: CVTL025U99% pure, hard pressed, 8 Oz. chlorine tabs provide safe, clean and sanitized water.Description•\t99% Trichlor Chlorine•\tNo gummy binders•\tHard-pressed 8 Oz tabs•\tNo film or clogging of skimmers, chlorinators, or filters•\tEnsures safe, sanitary, and sparkling water•\tUnwrapped•\tSanitizer / Sanitizers',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/clearview-tabs-25-lbajj.html',
#   'Manufacturer SKU': 'CVTL025U',
#   'Size': '25 lb',
#   'Brand': 'OREQ'},
#  {'title': 'ClearView Tabs 50 lb | CVTL050U',
#   'overview': 'ClearView 3" Jumbo Tab Unwrapped Pail, 50 Lb',
#   'price': '$214.95',
#   'stock': 'In stock',
#   'description': 'Jumbo Tabs 3"Part: CVTL050U99% pure, hard pressed, 8 Oz. chlorine tabs provide safe, clean and sanitized water.Description•\t99% Trichlor Chlorine•\tNo gummy binders•\tHard-pressed 8 Oz tabs•\tNo film or clogging of skimmers, chlorinators, or filters•\tEnsures safe, sanitary, and sparkling water•\tUnwrapped•\tSanitizer / Sanitizers',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/clearview-tabs-50-lbsvg.html',
#   'Manufacturer SKU': 'CVTL050U',
#   'Size': '50 lb',
#   'Brand': 'OREQ'},
#  {'title': "Shimmer N' Shock DiChlor 1 lb 24pk | CVDB001PK24",
#   'overview': 'Shimmer n Shock Dc 1 lb 24pk',
#   'price': '$197.95',
#   'stock': 'Out of stock',
#   'description': "Shimmer-N' ShockPart: Multiple - CVDB001PK24Chlorine-based shock treatment to control bacteria and algae.Description•\tActive Ingredient: 99% Sodium Dichlor•\tNo pre-dissolving•\tCompletely soluble•\tNo residue•\tWill not cause pH bounce•\tEconomical shock treatment•\tRestores sparkle and clarity to dull water•\tPerfect for vinyl-lined or above ground pools•\tShock/shocks",
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/shimmer-n-shock-dichlor-1-lb-24pkcem.html',
#   'Manufacturer SKU': 'CVDB001PK24',
#   'Size': '24 lb',
#   'Brand': 'OREQ'},
#  {'title': 'Shock & Swim 15 1 lb 24pk | CVCF001PK24',
#   'overview': 'Shock & Swim 15 1 lb 24pk',
#   'price': '$119.95',
#   'stock': 'Out of stock',
#   'description': 'Chlor Free Shock & Swim 15Part: CVCF001PK24Non-chlorine shock oxidizer removes organic contaminants and improves water clarity.Description•\tActive Ingredient: 45% Potassium Monopersulfate•\tRemoves chloramines•\tSafe with Chlorine, Bromine, and copper/silver sanitizer systems•\tWill not raise Chlorine to unsafe levels•\tRe-enter pool as quickly as 15 minutes after application•\tRestores sparkle and clarity to dull water•\tWill not bleach or fade vinyl liners•\tShock/shocks',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/shock-swim-15-1-lb-24pkaji.html',
#   'Manufacturer SKU': 'CVCF001PK24',
#   'Size': '24 lb',
#   'Brand': 'OREQ'},
#  {'title': 'Solar Pineapple Chlorinator | 12427',
#   'overview': 'Solar Light Up Pineapple Chlorinator',
#   'price': '$39.95',
#   'stock': 'In stock',
#   'description': 'N/A',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/solar-pineapple-chlorinatorkxr.html',
#   'Manufacturer SKU': '12427',
#   'Brand': 'GAME'},
#  {'title': 'PL 1" Tabs 5lb | 42104',
#   'overview': 'Poolife 1" Cleaning Tablets',
#   'price': '$56.95',
#   'stock': 'In stock',
#   'description': 'N/A',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/pl-1-tabs-5lbphj.html',
#   'Manufacturer SKU': '42104',
#   'Size': '5 lb',
#   'Brand': 'POOLIFE'},
#  {'title': 'PL Active Cleaning Granules 100 lb | 22230',
#   'overview': 'Poolife Active Cleaning Granules 68% Cal-Hypo Granular',
#   'price': '$328.95',
#   'stock': 'In stock',
#   'description': 'N/A',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/pl-active-cleaning-granules-100-lbhjn.html',
#   'Manufacturer SKU': '22230',
#   'Size': '100 lb',
#   'Brand': 'POOLIFE'},
#  {'title': 'PL Back To Blue 1 KIT | 92106',
#   'overview': 'Poolife Back To Blue',
#   'price': '$38.95',
#   'stock': 'Out of stock',
#   'description': 'N/A',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/pl-back-to-blue-1-kitjqb.html',
#   'Manufacturer SKU': '92106',
#   'Size': '4.6 lb',
#   'Brand': 'POOLIFE'},
#  {'title': 'PL MPT Tabs 11lb | 42121',
#   'overview': 'Poolife MPT Extra',
#   'price': '$109.95',
#   'stock': 'Out of stock',
#   'description': 'N/A',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/pl-mpt-tabs-11lbuat.html',
#   'Manufacturer SKU': '42121',
#   'Size': '11 lb',
#   'Brand': 'POOLIFE'},
#  {'title': 'PL NST Prime 39.4lb | 22426',
#   'overview': 'Poolife NST Prime 70% Cal-Hypo Tablet, 39.4lb.',
#   'price': '$296.95',
#   'stock': 'In stock',
#   'description': 'N/A',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/pl-nst-prime-39-4lblvk.html',
#   'Manufacturer SKU': '22426',
#   'Size': '39.4 lb',
#   'Brand': 'POOLIFE'},
#  {'title': 'PL Rapid Shock 1 lb | 22232',
#   'overview': 'Poolife Rapid Shock',
#   'price': '$6.95',
#   'stock': 'In stock',
#   'description': 'Poolife™ Rapid Shock™ Shock TreatmentQuickly brings chlorine levels into balance after heavy pool usage and after rain or windstorms. It works fast to rid the pool water of contaminants and keep it ready for a refreshing, clean swim.•\tAfter a good pool party—or a good rain or windstorm—contaminants can build up in your pool water•\tPoolife™ Rapid Shock works fast to clear contaminants, so your pool water is ready for your next clean, refreshing swim•\tCal Hypo formula quickly brings chlorine levels into balance without adding additional cyanuric acid (CYA)•\tUse Poolife™ Rapid Shock to shock treat your pool water once a week—no need to pre-mix•\tFor best results, test and balance your pool water then follow the easy step-by-step, on-pack instructions to shock treat•\tActive ingredient: 68% Calcium Hypochlorite (Cal Hypo)',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/pl-rapid-shock-1-lbmjh.html',
#   'Manufacturer SKU': '22232',
#   'Size': '1 lb',
#   'Brand': 'POOLIFE'},
#  {'title': 'PL Rapid Shock 1 lb 12pk | 22232PK12',
#   'overview': 'Poolife Rapid Shock 1 lb 12pk',
#   'price': '$69.95',
#   'stock': 'In stock',
#   'description': 'Poolife™ Rapid Shock™ Shock TreatmentQuickly brings chlorine levels into balance after heavy pool usage and after rain or windstorms. It works fast to rid the pool water of contaminants and keep it ready for a refreshing, clean swim.•\tAfter a good pool party—or a good rain or windstorm—contaminants can build up in your pool water•\tPoolife™ Rapid Shock works fast to clear contaminants, so your pool water is ready for your next clean, refreshing swim•\tCal Hypo formula quickly brings chlorine levels into balance without adding additional cyanuric acid (CYA)•\tUse Poolife™ Rapid Shock to shock treat your pool water once a week—no need to pre-mix•\tFor best results, test and balance your pool water then follow the easy step-by-step, on-pack instructions to shock treat•\tActive ingredient: 68% Calcium Hypochlorite (Cal Hypo)',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/pl-rapid-shock-1-lb-12pkxgm.html',
#   'Manufacturer SKU': '22232PK12',
#   'Size': '12 lb',
#   'Brand': 'POOLIFE'},
#  {'title': 'PL Rapid Shock 1 lb 24pk | 22232PK24',
#   'overview': 'Poolife Rapid Shock 1 lb 24pk',
#   'price': '$131.95',
#   'stock': 'Out of stock',
#   'description': 'Poolife™ Rapid Shock™ Shock TreatmentQuickly brings chlorine levels into balance after heavy pool usage and after rain or windstorms. It works fast to rid the pool water of contaminants and keep it ready for a refreshing, clean swim.•\tAfter a good pool party—or a good rain or windstorm—contaminants can build up in your pool water•\tPoolife™ Rapid Shock works fast to clear contaminants, so your pool water is ready for your next clean, refreshing swim•\tCal Hypo formula quickly brings chlorine levels into balance without adding additional cyanuric acid (CYA)•\tUse Poolife™ Rapid Shock to shock treat your pool water once a week—no need to pre-mix•\tFor best results, test and balance your pool water then follow the easy step-by-step, on-pack instructions to shock treat•\tActive ingredient: 68% Calcium Hypochlorite (Cal Hypo)',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/pl-rapid-shock-1-lb-24pkcln.html',
#   'Manufacturer SKU': '22232PK24',
#   'Size': '24 lb',
#   'Brand': 'POOLIFE'},
#  {'title': 'PL Rapid Shock 5 lb | 22212',
#   'overview': 'Poolife Rapid Shock 5lb',
#   'price': '$33.95',
#   'stock': 'In stock',
#   'description': 'Poolife™ Rapid Shock™ Shock TreatmentQuickly brings chlorine levels into balance after heavy pool usage and after rain or windstorms. It works fast to rid the pool water of contaminants and keep it ready for a refreshing, clean swim.•\tAfter a good pool party—or a good rain or windstorm—contaminants can build up in your pool water•\tPoolife™ Rapid Shock works fast to clear contaminants, so your pool water is ready for your next clean, refreshing swim•\tCal Hypo formula quickly brings chlorine levels into balance without adding additional cyanuric acid (CYA)•\tUse Poolife™ Rapid Shock to shock treat your pool water once a week—no need to pre-mix•\tFor best results, test and balance your pool water then follow the easy step-by-step, on-pack instructions to shock treat•\tActive ingredient: 68% Calcium Hypochlorite (Cal Hypo)',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/pl-rapid-shock-5-lbdwd.html',
#   'Manufacturer SKU': '22212',
#   'Size': '5 lb',
#   'Brand': 'POOLIFE'},
#  {'title': 'PL TurboShock 1 lb 24pk | 22405PK24',
#   'overview': 'Poolife TurboShock 1 lb 24pk',
#   'price': '$121.95',
#   'stock': 'Out of stock',
#   'description': 'Poolife™ TurboShock™ Shock Treatment: Cal Hypo ShockSKUs: 22405, 22406, 22403, 22402, 62082 & 22404The strongest Cal Hypo shock product in the industry! Dissolves quickly and completely to combat algae and bacteria and keep pool water sparkling clean and clear with less work.•\tQuickly and easily combat algae and bacteria with the strongest Cal Hypo shock in the industry•\tStep 2 of the 3-step Poolife™ MPT Extra™ System, Poolife™ TurboShock keeps pool water clean and crystal clear•\tQuick-dissolving cal hypo shock, great for all pool surfaces•\tUse Poolife™ TurboShock to shock treat pool water once a week — no need to pre-dissolve Poolife’s cal hypo shock•\tFor best results, test and balance your pool water then follow the easy step-by-step, on-pack instructions to shock treat with Poolife cal hypo shock•\tActive ingredient: 78% Calcium Hypochlorite (Cal Hypo)',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/pl-turboshock-1-lb-24pkblm.html',
#   'Manufacturer SKU': '22405PK24',
#   'Size': '24 lb',
#   'Brand': 'POOLIFE'},
#  {'title': 'PL TurboShock 55x1 lb | 22406',
#   'overview': 'Poolife Turbo Shock Shock Treatment [55x 1 lb]',
#   'price': '$379.95',
#   'stock': 'Out of stock',
#   'description': 'Poolife™ TurboShock™ Shock Treatment: Cal Hypo ShockSKUs: 22405, 22406, 22403, 22402, 62082 & 22404The strongest Cal Hypo shock product in the industry! Dissolves quickly and completely to combat algae and bacteria and keep pool water sparkling clean and clear with less work.•\tQuickly and easily combat algae and bacteria with the strongest Cal Hypo shock in the industry•\tStep 2 of the 3-step Poolife™ MPT Extra™ System, Poolife™ TurboShock keeps pool water clean and crystal clear•\tQuick-dissolving cal hypo shock, great for all pool surfaces•\tUse Poolife™ TurboShock to shock treat pool water once a week — no need to pre-dissolve Poolife’s cal hypo shock•\tFor best results, test and balance your pool water then follow the easy step-by-step, on-pack instructions to shock treat with Poolife cal hypo shock•\tActive ingredient: 78% Calcium Hypochlorite (Cal Hypo)',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/pl-turboshock-55x1-lbmls.html',
#   'Manufacturer SKU': '22406',
#   'Size': '55 lb',
#   'Brand': 'POOLIFE'},
#  {'title': 'PL TurboShock 65 lb | 22404',
#   'overview': 'Poolife Turbo Shock Shock Treatment',
#   'price': '$391.95',
#   'stock': 'In stock',
#   'description': 'Poolife™ TurboShock™ Shock Treatment: Cal Hypo ShockSKUs: 22405, 22406, 22403, 22402, 62082 & 22404The strongest Cal Hypo shock product in the industry! Dissolves quickly and completely to combat algae and bacteria and keep pool water sparkling clean and clear with less work.•\tQuickly and easily combat algae and bacteria with the strongest Cal Hypo shock in the industry•\tStep 2 of the 3-step Poolife™ MPT Extra™ System, Poolife™ TurboShock keeps pool water clean and crystal clear•\tQuick-dissolving cal hypo shock, great for all pool surfaces•\tUse Poolife™ TurboShock to shock treat pool water once a week — no need to pre-dissolve Poolife’s cal hypo shock•\tFor best results, test and balance your pool water then follow the easy step-by-step, on-pack instructions to shock treat with Poolife cal hypo shock•\tActive ingredient: 78% Calcium Hypochlorite (Cal Hypo)',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/pl-turboshock-65-lbjmn.html',
#   'Manufacturer SKU': '22404',
#   'Size': '65 lb',
#   'Brand': 'POOLIFE'},
#  {'title': 'Pink Flamingo Chlorine Dispenser | 32123',
#   'overview': 'Pink Flamingo Chlorine Dispenser',
#   'price': '$33.95',
#   'stock': 'Out of stock',
#   'description': 'N/A',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/pink-flamingo-chlorine-dispenserwnf.html',
#   'Manufacturer SKU': '32123',
#   'Brand': 'POOLMASTER'},
#  {'title': 'Mallard Chlorine Dispenser | 32130',
#   'overview': 'Mallard Chlorine Dispenser',
#   'price': '$33.95',
#   'stock': 'In stock',
#   'description': 'N/A',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/mallard-chlorine-dispenseryfv.html',
#   'Manufacturer SKU': '32130',
#   'Brand': 'POOLMASTER'},
#  {'title': 'NBA Basketball Chlorine Dispenser | 32136',
#   'overview': 'NBA Basketball Chlorine Dispenser',
#   'price': '$33.95',
#   'stock': 'In stock',
#   'description': 'N/A',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/nba-basketball-chlorine-dispenserymo.html',
#   'Manufacturer SKU': '32136',
#   'Brand': 'POOLMASTER'},
#  {'title': 'NST Floater | 92052',
#   'overview': 'NST Floater',
#   'price': '$21.95',
#   'stock': 'Out of stock',
#   'description': 'Poolife™ NST™ Chlorine Floater: Cal Hypo Pool Chlorine FloaterSKUs: 92052Bring Cal Hypo to the pool party with this exclusive new pool chlorine floater! It’s designed for Poolife™ NST™ Prime Tablets but works with any tablet*. The patent pending micro-mesh design slowly dissolves Poolife™ NST™ Prime Tablets so you can enjoy visibly brilliant pool water that lasts longer—with no risk of chlorine lock.•\tThe only pool chlorine floater made exclusively for NST™ Prime Tablets—no risk of chlorine lock•\tWorks most effectively with (4) Poolife™ NST™ Prime Tablets, but is compatible with all floater tablets*•\tThe patent-pending micro-mesh design slowly dissolves Cal Hypo tablets so pool water stays brilliantly clear for longer•\tOur pool chlorine floater is made with durable, long-lasting UV-resistant material with easy twist locking cap—no dials or set up required•\tTreats up to 20,000-gallon pools for up to 10 days•\tPoolife™ sanitizers and accessories are quick, convenient and easy-to-use so you can live your best pool lifeDisclaimer:*Never place Cal Hypo and Trichlor tablets in the floater at the same time.',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/nst-floatermco.html',
#   'Manufacturer SKU': '92052',
#   'Brand': 'POOLIFE'},
#  {'title': 'Deluxe Tab Floater | CL290ABW',
#   'overview': 'Deluxe Tab Floater',
#   'price': '$20.95',
#   'stock': 'Out of stock',
#   'description': '3" Tab ChlorinatorPart: CL290ABWChlorinator for use with 3" tabsDescription•\tChlorinators•\tColor: Blue & white•\t4 lb. Capacity•\tFor use with 3" tabs•\tReplacement Lid #RP290',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/deluxe-tab-floateraqz.html',
#   'Manufacturer SKU': 'CL290ABW',
#   'Brand': 'OREQ'},
#  {'title': 'AB Power Blast 70, 100 lb | 40710',
#   'overview': 'Applied Biochemists Power Blast 70',
#   'price': '$396.95',
#   'stock': 'Out of stock',
#   'description': 'Applied Biochemists® Power Blast 70 GranularPower Blast 70 Granular is a quick dissolving product that shocks, clarifies and oxidizes without adding cyanuric acid, effectively killing bacteria, controlling algae and destroying organic contaminants. Cal Hypo – no overstablization or chlorine lock.Shock treat at least once a weekNo need to pre-dissolveEnsure pH is correct before shock treating your pool',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/ab-power-blast-70-100-lbcyp.html',
#   'Manufacturer SKU': '40710',
#   'Size': '100 lb',
#   'Brand': 'APPLIED BIO'},
#  {'title': 'Algaecure 2 lb | CVTC002',
#   'overview': 'ClearView Algaecure Bottle, 2 Lb',
#   'price': '$33.95',
#   'stock': 'Out of stock',
#   'description': 'AlgaecurePart: CVTC002Algaecure can be used as a super chlorinator and effective algaecide for black algae in white plaster pools, leaving safe, sanitary, sparkling water.Description•\tActive Ingredient: 99% Trichlor•\tCan be used as a super chlorinator•\tEffective algaecide/algaecides for black algae in white plaster pools•\tEnsures safe, sanitary, sparkling clean water',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/algaecure-2-lbwjh.html',
#   'Manufacturer SKU': 'CVTC002',
#   'Size': '2 lb',
#   'Brand': 'OREQ'},
#  {'title': 'Algaecure 50 lb | CVTC050',
#   'overview': 'ClearView Algaecure Pail, 50 Lb',
#   'price': '$263.95',
#   'stock': 'Out of stock',
#   'description': 'AlgaecurePart: CVTC050Algaecure can be used as a super chlorinator and effective algaecide for black algae in white plaster pools, leaving safe, sanitary, sparkling water.Description•\tActive Ingredient: 99% Trichlor•\tCan be used as a super chlorinator•\tEffective algaecide/algaecides for black algae in white plaster pools•\tEnsures safe, sanitary, sparkling clean water',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/algaecure-50-lbofc.html',
#   'Manufacturer SKU': 'CVTC050',
#   'Size': '50 lb',
#   'Brand': 'OREQ'},
#  {'title': 'Trichlor Granular Ezchlor 50 lb | 12000536',
#   'overview': 'Trichlor Granular Ezchlor 50Lb',
#   'price': '$216.95',
#   'stock': 'Out of stock',
#   'description': 'N/A',
#   'link': 'https://www.freshpoolsupply.com/chemical/chlorine/trichlor-granular-ezchlor-50-lbxdm.html',
#   'Manufacturer SKU': '12000536',
#   'Size': '50 lb',
#   'Brand': 'EZ-CLOR'}]
