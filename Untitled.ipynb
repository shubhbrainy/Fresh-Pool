# %%
import pandas as pd

# %%
df_1 = pd.read_csv('bestpoolshop_chlorine.csv')
df_1.head()
# Out:
#                                                title  \
# 0  22421 Poolife NST Non Stabilized Swimming Pool...
# 1  22422 Poolife NST Non Stabilized Swimming Pool...
# 2  Bulk 50lb 3inch Chlorine Tablets For Swimming ...
# 3  CVBR004 Clearview Bromo Bromine Brominating 1i...
# 4  CVTLST005 ClearView Swimming Pool Spa Chlorine...
#
#                                             overview    price in_store_price  \
# 0  Use only in pools with a skimmer and skimmer b...  $185.76        $171.99
# 1  Use only in pools with a skimmer and skimmer b...      NaN        $234.99
# 2  Do not allow this product to get damp or wet b...      NaN       $1500.00
# 3  96% Bromine, Slow dissolving, Reduced odor, En...   $71.99         $64.99
# 4  World’s First Low-Odor Chlorine TabsExperience...   $48.99         $41.99
#
#                   stock                                        description  \
# 0  Only 7 left in stock  Poolife NST Non Stabilized Without Conditioner...
# 1            1 in stock  Poolife NST Non Stabilized Without Conditioner...
# 2            2 in stock  Swimming Pool 3 inch Stabilized Chlorine Table...
# 3  Only 8 left in stock  Oreq Clearview Swimming Pool and Spa Bromo Bro...
# 4  Only 3 left in stock  CVTLST005 Scent-Trific ClearView Swimming Pool...
#
#                                                 link  product_id  \
# 0  https://bestpoolshop.com/product/poolife-nst-n...       36140
# 1  https://bestpoolshop.com/product/poolife-nst-n...       80944
# 2  https://bestpoolshop.com/product/50lb-3inch-ch...      110412
# 3  https://bestpoolshop.com/product/clearview-bro...      119703
# 4  https://bestpoolshop.com/product/cvtlst005-cle...      137117
#
#   Calcium Hypochlorite Other Ingredients Trichlor-s-Triazinetrione  \
# 0                70.2%             29.8%                       NaN
# 1                70.2%             29.8%                       NaN
# 2                  NaN                1%                       99%
# 3                  NaN               NaN                       NaN
# 4                  NaN               NaN                       NaN
#
#   Available Chlorine                               ACTIVE INGREDIENT  \
# 0                NaN                                             NaN
# 1                NaN                                             NaN
# 2                90%                                             NaN
# 3                NaN  1-Bromo-3-chloro-5,5-dimethylhydantoin – 96.0%
# 4                NaN                                             NaN
#
#   Manufacturer SKU
# 0            22421
# 1            22422
# 2              NaN
# 3          CVBR004
# 4        CVTLST005

# %%
df_2 = pd.read_csv('chlorine_data.csv')
df_2.head()
# Out:
#                                                title  \
# 0                          AB 3" Tabs 50 lb | 40631A
# 1               Floating Chlorinator | 58470-110-690
# 2  Scent-Trific 3" Jumbo Tab 35lb Box of 70 | CVT...
# 3            Shock & Swim 15 1 lb 12pk | CVCF001PK12
# 4                    Shock & Swim 15 50 lb | CVCF050
#
#                                             overview    price         stock  \
# 0                     Applied Biochemists 3" Tablets  $284.95  Out of stock
# 1        Floating Chemical Dispenser For 3In Tablets   $15.95      In stock
# 2  ClearView Scent-Trific Tabs Full Strength, Low...  $359.95  Out of stock
# 3                          Shock & Swim 15 1 lb 12pk   $59.95  Out of stock
# 4  ClearView Shock & Swim 15, Chlorine Free Shock...  $220.95      In stock
#
#                                          description  \
# 0  Applied Biochemists® 3” TabletsSlow dissolving...
# 1                                                NaN
# 2  Scent-Trific Jumbo Tabs 3Scent-Trific Chlorine...
# 3  Chlor Free Shock &amp; Swim 15Part: CVCF001PK1...
# 4  Chlor Free Shock &amp; Swim 15Part: CVCF050Non...
#
#                                                 link Manufacturer SKU   Size  \
# 0  https://www.freshpoolsupply.com/chemical/chlor...           40631A  50 lb
# 1  https://www.freshpoolsupply.com/chemical/chlor...    58470-110-690    NaN
# 2  https://www.freshpoolsupply.com/chemical/chlor...      CVTLSTCR035  8  Oz
# 3  https://www.freshpoolsupply.com/chemical/chlor...      CVCF001PK12  12 lb
# 4  https://www.freshpoolsupply.com/chemical/chlor...          CVCF050  50 lb
#
#          Brand
# 0  APPLIED BIO
# 1          CMP
# 2         OREQ
# 3         OREQ
# 4         OREQ

# %%
df_3 = pd.read_csv('epoolsupply_chlorine.csv')
df_3.head()
# Out:
#                                         Title  \
# 0    Poolife 3" Chlorine Tabs (50lbs) | 42118
# 1  Poolife 1" Cleaning Tablets | 42104 (5LBS)
# 2    Poolife Bromine Tablets | 25 LBS (62182)
# 3         Poolife NST Prime Tablets | 4.5 LBS
# 4   Poolife NST Prime Tablets | 9 LBS (22424)
#
#                                             Overview    Price         Stock  \
# 0  steady, consistent chlorination | sanitized, c...  $169.95      In stock
# 1  pool maintenance | 1-inch trichlor tablets | k...   $52.99      In stock
# 2  slow-dissolving tablets | continuous disinfect...  $299.00  Out of stock
# 3  chlorine | oxidizers | stabilizers | residenti...   $41.99  Out of stock
# 4  slow-dissolving tablets | chlorine sanitizers ...   $72.99  Out of stock
#
#                                          Description  \
# 0  Poolife 3" Chlorine Tabs arehighly effective c...
# 1  Poolife 1" Cleaning Tablets arehighly effectiv...
# 2                                      Key Features:
# 3  Poolife NST Prime Tablets are designed forpool...
# 4  Poolife NST Prime Tablets in the9 LBSsize are ...
#
#                                                 Link Manufacturer SKU  \
# 0  https://www.epoolsupply.com/collections/poolif...            42118
# 1  https://www.epoolsupply.com/collections/poolif...            42104
# 2  https://www.epoolsupply.com/collections/poolif...            62182
# 3  https://www.epoolsupply.com/collections/poolif...            22427
# 4  https://www.epoolsupply.com/collections/poolif...            22424
#
#                            Brand
# 0  Poolife Chlorine & Sanitizers
# 1  Poolife Chlorine & Sanitizers
# 2  Poolife Chlorine & Sanitizers
# 3  Poolife Chlorine & Sanitizers
# 4  Poolife Chlorine & Sanitizers

# %%
df_4 = pd.read_csv('poolweb_chlorine.csv')
df_4.head()
# Out:
#                                                title  \
# 0  Pool Season Chlorinating Tablets Wrapped - 3 I...
# 1  Pool Season Chlorinating Tablets Wrapped - 3 I...
# 2  Pool Season Chlorinating Tablets Wrapped - 3 I...
# 3  Pool Season Non-Chlorine Shock Oxidizer - 1 Lb...
# 4  Pool Season Chlorinating Concentrate - 50 Lb. ...
#
#                                             overview    price         stock  \
# 0  3 inch wrapped tablets | 90% available chlorin...  $277.33  209 in stock
# 1  3 inch wrapped tablets | 90% available chlorin...  $147.01  225 in stock
# 2  3 inch wrapped tablets | 90% available chlorin...   $79.82  200 in stock
# 3  Non-chlorine oxidizer will not raise chlorine ...   $13.85  248 in stock
# 4  Stabilized chlorinating concentrate | Totally ...  $334.29  214 in stock
#
#                                          description  \
# 0  Description The Pool Season Chlorinating Table...
# 1  Description The Pool Season Chlorinating Table...
# 2  Description The Pool Season Chlorinating Table...
# 3  Description The Pool Season Non-Chlorine Shock...
# 4  Description This is a 50 pound bucket of Pool ...
#
#                                                 link Product Category  \
# 0  https://www.poolweb.com/products/pool-season-c...         Chlorine
# 1  https://www.poolweb.com/products/pool-season-c...         Chlorine
# 2  https://www.poolweb.com/products/pool-season-c...         Chlorine
# 3  https://www.poolweb.com/products/pool-season-n...         Chlorine
# 4  https://www.poolweb.com/products/pool-season-c...         Chlorine
#
#   Poolweb Item # Cross Reference # Manufacturer Shipping Weight
# 0    HGH-50-3750          47251280  Pool Season         52.0 lb
# 1    HGH-50-3725          47251270  Pool Season         27.0 lb
# 2    HGH-50-3708          47251260  Pool Season         10.0 lb
# 3    HGH-50-2849          47251330  Pool Season          2.0 lb
# 4    HGH-50-2650          47251320  Pool Season         52.0 lb

# %%
df_2.columns
# Out:
# Index(['title', 'overview', 'price', 'stock', 'description', 'link',
#        'Manufacturer SKU', 'Size', 'Brand'],
#       dtype='object')

# %%
def lowercase_columns(df):
    df.columns = [col.lower() for col in df.columns]
    return df

# %%
df_1 = lowercase_columns(df_1)
df_2 = lowercase_columns(df_2)
df_3 = lowercase_columns(df_3)
df_4 = lowercase_columns(df_4)

# %%
df_1.head()
# Out:
#                                                title  \
# 0  22421 Poolife NST Non Stabilized Swimming Pool...
# 1  22422 Poolife NST Non Stabilized Swimming Pool...
# 2  Bulk 50lb 3inch Chlorine Tablets For Swimming ...
# 3  CVBR004 Clearview Bromo Bromine Brominating 1i...
# 4  CVTLST005 ClearView Swimming Pool Spa Chlorine...
#
#                                             overview    price in_store_price  \
# 0  Use only in pools with a skimmer and skimmer b...  $185.76        $171.99
# 1  Use only in pools with a skimmer and skimmer b...      NaN        $234.99
# 2  Do not allow this product to get damp or wet b...      NaN       $1500.00
# 3  96% Bromine, Slow dissolving, Reduced odor, En...   $71.99         $64.99
# 4  World’s First Low-Odor Chlorine TabsExperience...   $48.99         $41.99
#
#                   stock                                        description  \
# 0  Only 7 left in stock  Poolife NST Non Stabilized Without Conditioner...
# 1            1 in stock  Poolife NST Non Stabilized Without Conditioner...
# 2            2 in stock  Swimming Pool 3 inch Stabilized Chlorine Table...
# 3  Only 8 left in stock  Oreq Clearview Swimming Pool and Spa Bromo Bro...
# 4  Only 3 left in stock  CVTLST005 Scent-Trific ClearView Swimming Pool...
#
#                                                 link  product_id  \
# 0  https://bestpoolshop.com/product/poolife-nst-n...       36140
# 1  https://bestpoolshop.com/product/poolife-nst-n...       80944
# 2  https://bestpoolshop.com/product/50lb-3inch-ch...      110412
# 3  https://bestpoolshop.com/product/clearview-bro...      119703
# 4  https://bestpoolshop.com/product/cvtlst005-cle...      137117
#
#   calcium hypochlorite other ingredients trichlor-s-triazinetrione  \
# 0                70.2%             29.8%                       NaN
# 1                70.2%             29.8%                       NaN
# 2                  NaN                1%                       99%
# 3                  NaN               NaN                       NaN
# 4                  NaN               NaN                       NaN
#
#   available chlorine                               active ingredient  \
# 0                NaN                                             NaN
# 1                NaN                                             NaN
# 2                90%                                             NaN
# 3                NaN  1-Bromo-3-chloro-5,5-dimethylhydantoin – 96.0%
# 4                NaN                                             NaN
#
#   manufacturer sku
# 0            22421
# 1            22422
# 2              NaN
# 3          CVBR004
# 4        CVTLST005

# %%
def restructure_df(df):
    """
    Keeps only ['title', 'overview', 'price', 'stock', 'description', 'link'] columns.
    Merges any additional columns into 'description' with labels.

    Parameters:
        df (pd.DataFrame): The input DataFrame

    Returns:
        pd.DataFrame: Modified DataFrame with merged description
    """
    
    # Core columns to retain
    final_cols = ['title', 'overview', 'price', 'stock', 'description', 'link']
    
    # Identify extra columns
    extra_cols = [col for col in df.columns if col not in final_cols]

    # Merge extra columns into description
    df['description'] = df.apply(
        lambda row: f"{row['description']} " + 
                    " ".join([f"{col}: {row[col]}" for col in extra_cols if pd.notna(row[col])]), 
        axis=1
    )

    # Keep only final columns
    return df[final_cols]

# %%
df_1_new = restructure_df(df_1)
df_2_new = restructure_df(df_2)
df_3_new = restructure_df(df_3)
df_4_new = restructure_df(df_4)

# %%
df_4_new.head()
# Out:
#                                                title  \
# 0  Pool Season Chlorinating Tablets Wrapped - 3 I...
# 1  Pool Season Chlorinating Tablets Wrapped - 3 I...
# 2  Pool Season Chlorinating Tablets Wrapped - 3 I...
# 3  Pool Season Non-Chlorine Shock Oxidizer - 1 Lb...
# 4  Pool Season Chlorinating Concentrate - 50 Lb. ...
#
#                                             overview    price         stock  \
# 0  3 inch wrapped tablets | 90% available chlorin...  $277.33  209 in stock
# 1  3 inch wrapped tablets | 90% available chlorin...  $147.01  225 in stock
# 2  3 inch wrapped tablets | 90% available chlorin...   $79.82  200 in stock
# 3  Non-chlorine oxidizer will not raise chlorine ...   $13.85  248 in stock
# 4  Stabilized chlorinating concentrate | Totally ...  $334.29  214 in stock
#
#                                          description  \
# 0  Description The Pool Season Chlorinating Table...
# 1  Description The Pool Season Chlorinating Table...
# 2  Description The Pool Season Chlorinating Table...
# 3  Description The Pool Season Non-Chlorine Shock...
# 4  Description This is a 50 pound bucket of Pool ...
#
#                                                 link
# 0  https://www.poolweb.com/products/pool-season-c...
# 1  https://www.poolweb.com/products/pool-season-c...
# 2  https://www.poolweb.com/products/pool-season-c...
# 3  https://www.poolweb.com/products/pool-season-n...
# 4  https://www.poolweb.com/products/pool-season-c...
