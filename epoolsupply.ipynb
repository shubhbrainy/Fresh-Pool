# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

base_url = "https://www.epoolsupply.com"
start_url = f"{base_url}/collections/pool-chlorine-tabs"
headers = {"User-Agent": "Mozilla/5.0"}

all_products = []

# Step 1: Extract category names and links
resp = requests.get(start_url, headers=headers)
soup = BeautifulSoup(resp.text, 'html.parser')

category_data = []

category_blocks = soup.select("div.subcat-grid-item.subcat-type-collection.subcat-shown")
for div in category_blocks:
    a_tag = div.find("a", class_="subcat-grid-link")
    title_tag = div.find("p", class_="subcat-grid-link__title")
    if a_tag and title_tag:
        category_name = title_tag.get_text(strip=True).split('(')[0].strip()
        category_href = a_tag.get("href")
        full_category_url = base_url + category_href
        category_data.append((category_name, full_category_url))

# Step 2 & 3: For each category, extract product links and info
for cat_name, cat_url in category_data:
    print(f"\nCategory: {cat_name}\nURL: {cat_url}")
    try:
        res = requests.get(cat_url, headers=headers)
        cat_soup = BeautifulSoup(res.text, 'html.parser')
        product_tags = cat_soup.select("li.js-pagination-result p.card__title a")

        for tag in product_tags:
            href = tag.get("href")
            if href:
                full_product_link = base_url + href
                print(full_product_link)

                try:
                    detail_resp = requests.get(full_product_link, headers=headers)
                    detail_soup = BeautifulSoup(detail_resp.text, 'html.parser')

                    # Title
                    title_elem = detail_soup.select_one('h1.product-title')
                    title = title_elem.get_text(strip=True) if title_elem else 'N/A'

                    # Price
                    price_main = detail_soup.select_one('div.product-price strong.price__current')
                    price_sup = detail_soup.select_one('div.product-price strong.price__current sup')
                    
                    if price_main:
                        price_text = price_main.get_text(strip=True).replace('USD', '').strip()
                        if price_sup:
                            sup_text = price_sup.get_text(strip=True)
                            price_text = price_text.replace(sup_text, '') + '.' + sup_text
                        price = price_text
                    else:
                        price = 'N/A'


                    # Stock
                    add_btn = detail_soup.select_one('product-form button[name="add"]')
                    stock = 'In stock' if add_btn and 'add to cart' in add_btn.get_text(strip=True).lower() else 'Out of stock'

                    # Description (first p[data-start])
                    desc_elem = detail_soup.select_one('div.product-description p[data-start]')
                    description = desc_elem.get_text(strip=True) if desc_elem else 'N/A'

                    # Overview (strong[data-start] inside p)
                    overview_elements = detail_soup.select('div.product-description p strong[data-start]')
                    overview = ' | '.join(elem.get_text(strip=True) for elem in overview_elements[1:]) if len(overview_elements) > 1 else 'N/A'


                    # Manufacturer SKU
                    sku_elem = detail_soup.select_one('span.product-sku__value')
                    manufacturer_sku = sku_elem.get_text(strip=True) if sku_elem else 'N/A'

                    # Append
                    all_products.append({
                        'Title': title,
                        'Overview': overview,
                        'Price': price,
                        'Stock': stock,
                        'Description': description,
                        'Link': full_product_link,
                        'Manufacturer SKU': manufacturer_sku,
                        'Brand': cat_name
                    })

                    time.sleep(1)

                except Exception as e:
                    print(f"  ⚠ Failed to fetch product info from {full_product_link}: {e}")
    except Exception as e:
        print(f"  ⚠ Failed to process {cat_name} ({cat_url}): {e}")

# DataFrame
df = pd.DataFrame(all_products)
df.head()
# Out:
# Category: Poolife Chlorine & Sanitizers
# URL: https://www.epoolsupply.com/collections/poolife-chlorine-sanitizers-tabs
# https://www.epoolsupply.com/collections/poolife-chlorine-sanitizers-tabs/products/pool-logic-3-chlorine-tabs-50lbs
# https://www.epoolsupply.com/collections/poolife-chlorine-sanitizers-tabs/products/poolife-1-cleaning-tablets
# https://www.epoolsupply.com/collections/poolife-chlorine-sanitizers-tabs/products/poolife-bromine-tablets-25-lbs-62182
# https://www.epoolsupply.com/collections/poolife-chlorine-sanitizers-tabs/products/poolife-nst-prime-tablets-4-5-lbs
# https://www.epoolsupply.com/collections/poolife-chlorine-sanitizers-tabs/products/poolife-nst-prime-tablets-9-lbs-22424
# https://www.epoolsupply.com/collections/poolife-chlorine-sanitizers-tabs/products/poolife-nst-prime-tablets-20-2-lbs-22425
# https://www.epoolsupply.com/collections/poolife-chlorine-sanitizers-tabs/products/poolife-nst-prime-tablets-39-4-lbs-22426
# https://www.epoolsupply.com/collections/poolife-chlorine-sanitizers-tabs/products/poolife-3-cleaning-tablets-7-oz-42130
# https://www.epoolsupply.com/collections/poolife-chlorine-sanitizers-tabs/products/poolife-3-cleaning-tablets-4-81-lbs-42107
#
# Category: Sirona Chlorine & Sanitizers
# URL: https://www.epoolsupply.com/collections/sirona-chlorine-sanitizers-tabs
# https://www.epoolsupply.com/collections/sirona-chlorine-sanitizers-tabs/products/sirona-brom-tabs-82235
#
# Category: GLB Chlorine & Sanitizers
# URL: https://www.epoolsupply.com/collections/glb-chlorine-sanitizers-tabs
# https://www.epoolsupply.com/collections/glb-chlorine-sanitizers-tabs/products/glb-large-3-chlorine-tablets-71228a-4-lb
# https://www.epoolsupply.com/collections/glb-chlorine-sanitizers-tabs/products/glb-generation-bromine-tablets-71443-25-lb
# https://www.epoolsupply.com/collections/glb-chlorine-sanitizers-tabs/products/glb-triple-tab-71446a-22-5-lb-1
# https://www.epoolsupply.com/collections/glb-chlorine-sanitizers-tabs/products/glb-triple-tab-71445a-10-lb
# https://www.epoolsupply.com/collections/glb-chlorine-sanitizers-tabs/products/glb-small-1-chlorine-tablets-71239a-5-lb
# https://www.epoolsupply.com/collections/glb-chlorine-sanitizers-tabs/products/glb-large-3-chlorine-tablets-71236a-50-lb
# https://www.epoolsupply.com/collections/glb-chlorine-sanitizers-tabs/products/glb-large-3-chlorine-tablets-71234a-25-lb
# https://www.epoolsupply.com/collections/glb-chlorine-sanitizers-tabs/products/glb-longevity-cal-hypo-chlorine-tablets-71437-29-4-lbs
# https://www.epoolsupply.com/collections/glb-chlorine-sanitizers-tabs/products/glb-longevity-cal-hypo-chlorine-tablets-71434-20-lb
#
# Category: Applied Bio Chlorine & Sanitizers
# URL: https://www.epoolsupply.com/collections/applied-bio-chlorine-sanitizers-tabs
# https://www.epoolsupply.com/collections/applied-bio-chlorine-sanitizers-tabs/products/applied-biochemists-granular-chlorine-40697a-50-lb
# https://www.epoolsupply.com/collections/applied-bio-chlorine-sanitizers-tabs/products/applied-biochemists-oxytrine-40720-50-lb-pool-oxidizer
# https://www.epoolsupply.com/collections/applied-bio-chlorine-sanitizers-tabs/products/applied-biochemists-power-blast-70-40710-100lb-pool-shock-treatment
# https://www.epoolsupply.com/collections/applied-bio-chlorine-sanitizers-tabs/products/applied-biochemists-3-chlorine-tablets-40631a-50-lb
#
# Category: Leisure Time Chlorine & Sanitizers
# URL: https://www.epoolsupply.com/collections/leisure-time-chlorine-sanitizers-tabs
# https://www.epoolsupply.com/collections/leisure-time-chlorine-sanitizers-tabs/products/leisure-time-bromine-tabs-45404-1-bromine-tablets-for-spas-pools
#
# Category: Pool Season Chlorine & Sanitizers
# URL: https://www.epoolsupply.com/collections/pool-season-chlorine-sanitizers-tabs
# https://www.epoolsupply.com/collections/pool-season-chlorine-sanitizers-tabs/products/pool-season-chlorinating-tablets-50-lb-bucket
# https://www.epoolsupply.com/collections/pool-season-chlorine-sanitizers-tabs/products/pool-season-chlorinating-tablets-25-lb-bucket
# https://www.epoolsupply.com/collections/pool-season-chlorine-sanitizers-tabs/products/pool-season-chlorinating-tablets-8-lb-bucket
#                                         Title  \
# 0    Poolife 3" Chlorine Tabs (50lbs) | 42118
# 1  Poolife 1" Cleaning Tablets | 42104 (5LBS)
# 2    Poolife Bromine Tablets | 25 LBS (62182)
# 3         Poolife NST Prime Tablets | 4.5 LBS
# 4   Poolife NST Prime Tablets | 9 LBS (22424)
#
#                                             Overview    Price         Stock  \
# 0  steady, consistent chlorination | sanitized, c...  $169.95      In stock
# 1  pool maintenance | 1-inch trichlor tablets | k...   $52.99      In stock
# 2  slow-dissolving tablets | continuous disinfect...  $299.00  Out of stock
# 3  chlorine | oxidizers | stabilizers | residenti...   $41.99  Out of stock
# 4  slow-dissolving tablets | chlorine sanitizers ...   $72.99  Out of stock
#
#                                          Description  \
# 0  Poolife 3" Chlorine Tabs arehighly effective c...
# 1  Poolife 1" Cleaning Tablets arehighly effectiv...
# 2                                      Key Features:
# 3  Poolife NST Prime Tablets are designed forpool...
# 4  Poolife NST Prime Tablets in the9 LBSsize are ...
#
#                                                 Link Manufacturer SKU  \
# 0  https://www.epoolsupply.com/collections/poolif...            42118
# 1  https://www.epoolsupply.com/collections/poolif...            42104
# 2  https://www.epoolsupply.com/collections/poolif...            62182
# 3  https://www.epoolsupply.com/collections/poolif...            22427
# 4  https://www.epoolsupply.com/collections/poolif...            22424
#
#                            Brand
# 0  Poolife Chlorine & Sanitizers
# 1  Poolife Chlorine & Sanitizers
# 2  Poolife Chlorine & Sanitizers
# 3  Poolife Chlorine & Sanitizers
# 4  Poolife Chlorine & Sanitizers

# %%
df
# Out:
#                                                 Title  \
# 0            Poolife 3" Chlorine Tabs (50lbs) | 42118
# 1          Poolife 1" Cleaning Tablets | 42104 (5LBS)
# 2            Poolife Bromine Tablets | 25 LBS (62182)
# 3                 Poolife NST Prime Tablets | 4.5 LBS
# 4           Poolife NST Prime Tablets | 9 LBS (22424)
# 5        Poolife NST Prime Tablets | 20.2 LBS (22425)
# 6        Poolife NST Prime Tablets | 39.4 LBS (22426)
# 7        Poolife 3" Cleaning Tablet | 1, 7 OZ (42130)
# 8      Poolife 3" Cleaning Tablets | 4.81 LBS (42107)
# 9                            Sirona Brom Tabs | 82235
# 10      GLB Large 3" Chlorine Tablets | 71228A | 4 LB
# 11     GLB Generation Bromine Tablets | 71443 | 25 LB
# 12                  GLB Triple Tab | 71446A | 22.5 LB
# 13                    GLB Triple Tab | 71445A | 10 LB
# 14      GLB Small 1" Chlorine Tablets | 71239A | 5 LB
# 15     GLB Large 3" Chlorine Tablets | 71236A | 50 LB
# 16     GLB Large 3" Chlorine Tablets | 71234A | 25 LB
# 17  GLB Longevity Cal Hypo Chlorine Tablets | 7143...
# 18  GLB Longevity Cal Hypo Chlorine Tablets | 7143...
# 19  Applied Biochemists Granular Chlorine 50 lb | ...
# 20  Applied Biochemists Oxytrine | 40720 | 50 lb |...
# 21  Applied Biochemists Power Blast 70 | 40710 | 1...
# 22  Applied Biochemists 3" Chlorine Tablets | 4063...
# 23  Leisure Time Bromine Tabs | 45404 | 1" Bromine...
# 24    POOL SEASON Chlorinating Tablets - 50 LB Bucket
# 25    POOL SEASON Chlorinating Tablets - 25 LB Bucket
# 26     POOL SEASON Chlorinating Tablets - 8 LB Bucket
#
#                                              Overview    Price         Stock  \
# 0   steady, consistent chlorination | sanitized, c...  $169.95      In stock
# 1   pool maintenance | 1-inch trichlor tablets | k...   $52.99      In stock
# 2   slow-dissolving tablets | continuous disinfect...  $299.00  Out of stock
# 3   chlorine | oxidizers | stabilizers | residenti...   $41.99  Out of stock
# 4   slow-dissolving tablets | chlorine sanitizers ...   $72.99  Out of stock
# 5   larger pools | chlorine | oxidizing | long-las...  $124.99  Out of stock
# 6   39.4 LBS | dual-action sanitization | oxidatio...  $276.99      In stock
# 7   sanitized and crystal clear | slow-dissolving ...    $6.99      In stock
# 8   sanitized and crystal clear | slow-dissolving ...   $42.99  Out of stock
# 9   effective and continuous sanitization | powerf...   $42.99      In stock
# 10  long-lasting, slow-dissolving | pool sanitizat...   $42.99  Out of stock
# 11  bromine-based pool systems | 25 LB pack | brom...  $326.99  Out of stock
# 12  triple-action formula | long-lasting, efficien...  $165.99  Out of stock
# 13  triple-action formula | long-lasting, efficien...   $94.99  Out of stock
# 14  fast-dissolving | pool sanitization | 5 lb pac...   $53.99  Out of stock
# 15  long-lasting, slow-release | clean, clear, and...  $309.99  Out of stock
# 16  long-lasting, slow-dissolving | consistent poo...  $160.99  Out of stock
# 17  powerful and long-lasting sanitization solutio...    $2.99  Out of stock
# 18  long-lasting pool sanitization | eliminate bac...  $120.99  Out of stock
# 19  fast-dissolving chlorine | pool sanitation | c...  $259.95      In stock
# 20  powerful pool oxidizer | organic contaminants ...  $404.99  Out of stock
# 21  pool shock treatment | clear cloudy water | el...  $437.99  Out of stock
# 22  chlorine tablets | consistent, long-lasting sa...  $315.99  Out of stock
# 23  1" bromine tablets | spa and pool sanitization...   $47.99  Out of stock
# 24                        Features: | Specifications:  $209.00  Out of stock
# 25                        Features: | Specifications:  $139.00  Out of stock
# 26                        Features: | Specifications:   $74.99  Out of stock
#
#                                           Description  \
# 0   Poolife 3" Chlorine Tabs arehighly effective c...
# 1   Poolife 1" Cleaning Tablets arehighly effectiv...
# 2                                       Key Features:
# 3   Poolife NST Prime Tablets are designed forpool...
# 4   Poolife NST Prime Tablets in the9 LBSsize are ...
# 5   Poolife NST Prime Tablets in the20.2 LBSsize a...
# 6   ThePoolife NST Prime Tabletsin the39.4 LBSsize...
# 7   Poolife 3" Cleaning Tablets providelong-lastin...
# 8   Poolife 3" Cleaning Tablets providelong-lastin...
# 9   The NEW Sirona Brom Tabs areslow-dissolving br...
# 10  GLB Large 3" Chlorine Tabletsprovide along-las...
# 11  GLB Generation Bromine Tabletsare designed spe...
# 12  GLB Triple Taboffers atriple-action formulatha...
# 13  GLB Triple Tabcombines the power of atriple-ac...
# 14  GLB Small 1" Chlorine Tabletsoffer an effectiv...
# 15  GLB Large 3" Chlorine Tabletsare designed forl...
# 16  GLB Large 3" Chlorine Tabletsoffer along-lasti...
# 17  GLB Longevity Cal Hypo Chlorine Tabletsoffer a...
# 18  GLB Longevity Cal Hypo Chlorine Tabletsare des...
# 19  Applied Biochemists Granular Chlorine(40697A) ...
# 20  Applied Biochemists Oxytrine(40720) is apowerf...
# 21  Applied Biochemists Power Blast 70(40710) is a...
# 22  Applied Biochemists 3" Chlorine Tablets(40631A...
# 23  The NEW Leisure Time Bromine Tabs(45404) are1"...
# 24  ThePOOL SEASON Chlorinating Tablets (50 LB Buc...
# 25  ThePOOL SEASON Chlorinating Tablets (25 LB Buc...
# 26  ThePOOL SEASON Chlorinating Tablets (8 LB Buck...
#
#                                                  Link Manufacturer SKU  \
# 0   https://www.epoolsupply.com/collections/poolif...            42118
# 1   https://www.epoolsupply.com/collections/poolif...            42104
# 2   https://www.epoolsupply.com/collections/poolif...            62182
# 3   https://www.epoolsupply.com/collections/poolif...            22427
# 4   https://www.epoolsupply.com/collections/poolif...            22424
# 5   https://www.epoolsupply.com/collections/poolif...            22425
# 6   https://www.epoolsupply.com/collections/poolif...            22426
# 7   https://www.epoolsupply.com/collections/poolif...            42130
# 8   https://www.epoolsupply.com/collections/poolif...            42107
# 9   https://www.epoolsupply.com/collections/sirona...            82235
# 10  https://www.epoolsupply.com/collections/glb-ch...           71228A
# 11  https://www.epoolsupply.com/collections/glb-ch...            71443
# 12  https://www.epoolsupply.com/collections/glb-ch...           71446A
# 13  https://www.epoolsupply.com/collections/glb-ch...           71445A
# 14  https://www.epoolsupply.com/collections/glb-ch...           71239A
# 15  https://www.epoolsupply.com/collections/glb-ch...           71236A
# 16  https://www.epoolsupply.com/collections/glb-ch...           71234A
# 17  https://www.epoolsupply.com/collections/glb-ch...            71437
# 18  https://www.epoolsupply.com/collections/glb-ch...            71434
# 19  https://www.epoolsupply.com/collections/applie...           40697A
# 20  https://www.epoolsupply.com/collections/applie...            40720
# 21  https://www.epoolsupply.com/collections/applie...            40710
# 22  https://www.epoolsupply.com/collections/applie...           40631A
# 23  https://www.epoolsupply.com/collections/leisur...            45404
# 24  https://www.epoolsupply.com/collections/pool-s...      HGH-50-3750
# 25  https://www.epoolsupply.com/collections/pool-s...      HGH-50-3725
# 26  https://www.epoolsupply.com/collections/pool-s...      HGH-50-3708
#
#                                  Brand
# 0        Poolife Chlorine & Sanitizers
# 1        Poolife Chlorine & Sanitizers
# 2        Poolife Chlorine & Sanitizers
# 3        Poolife Chlorine & Sanitizers
# 4        Poolife Chlorine & Sanitizers
# 5        Poolife Chlorine & Sanitizers
# 6        Poolife Chlorine & Sanitizers
# 7        Poolife Chlorine & Sanitizers
# 8        Poolife Chlorine & Sanitizers
# 9         Sirona Chlorine & Sanitizers
# 10           GLB Chlorine & Sanitizers
# 11           GLB Chlorine & Sanitizers
# 12           GLB Chlorine & Sanitizers
# 13           GLB Chlorine & Sanitizers
# 14           GLB Chlorine & Sanitizers
# 15           GLB Chlorine & Sanitizers
# 16           GLB Chlorine & Sanitizers
# 17           GLB Chlorine & Sanitizers
# 18           GLB Chlorine & Sanitizers
# 19   Applied Bio Chlorine & Sanitizers
# 20   Applied Bio Chlorine & Sanitizers
# 21   Applied Bio Chlorine & Sanitizers
# 22   Applied Bio Chlorine & Sanitizers
# 23  Leisure Time Chlorine & Sanitizers
# 24   Pool Season Chlorine & Sanitizers
# 25   Pool Season Chlorine & Sanitizers
# 26   Pool Season Chlorine & Sanitizers

# %%
df.to_csv('epoolsupply_chlorine.csv', index=False)

# %%
def print_row(df, row_index):
    if row_index < 0 or row_index >= len(df):
        print(f"Row index {row_index} is out of bounds (0 - {len(df)-1})")
        return

    row = df.iloc[row_index]

    print(f"\n--- Row {row_index} ---")
    for col in df.columns:
        value = str(row[col])  # Ensure it's a string for splitting
        print(f"{col}:")
        # Split on \n and print each line with indentation
        for line in value.split('\n'):
            print(f"  {line}")
        print("-" * 40)

# Example usage:
# df = pd.read_csv('your_file.csv')
# print_row(df, 2)  # View row at index 2

# %%
import pandas as pd 
df = pd.read_csv('epoolsupply_chlorine.csv')

# %%
print_row(df, 0)
# Out:
# --- Row 0 ---
# Title:
#   Poolife 3" Chlorine Tabs (50lbs) | 42118
# ----------------------------------------
# Overview:
#   steady, consistent chlorination | sanitized, clear, and safe | slow-dissolving, stabilized tablets | automatic feeders, skimmers, or floating dispensers | consistent | minimizing maintenance efforts | Key Features: | Usage Instructions: | Important Notes: | Benefits: | Poolife 3" Chlorine Tabs (50 LBS) | powerful, efficient, and reliable solution | consistent, long-term chlorination
# ----------------------------------------
# Price:
#   $169.95
# ----------------------------------------
# Stock:
#   In stock
# ----------------------------------------
# Description:
#   Poolife 3" Chlorine Tabs arehighly effective chlorine tabletsthat providesteady, consistent chlorinationto keep your pool watersanitized, clear, and safefor swimming. Theseslow-dissolving, stabilized tabletsare designed forautomatic feeders, skimmers, or floating dispensers, making them a convenient and reliable solution for long-term pool maintenance. Ideal for larger pools or frequent pool usage, these tablets ensure that chlorine levels remainconsistentwhileminimizing maintenance efforts.
# ----------------------------------------
# Link:
#   https://www.epoolsupply.com/collections/poolife-chlorine-sanitizers-tabs/products/pool-logic-3-chlorine-tabs-50lbs
# ----------------------------------------
# Manufacturer SKU:
#   42118
# ----------------------------------------
# Brand:
#   Poolife Chlorine & Sanitizers
# ----------------------------------------

# %%
df
# Out:
#                                                 Title  \
# 0            Poolife 3" Chlorine Tabs (50lbs) | 42118
# 1          Poolife 1" Cleaning Tablets | 42104 (5LBS)
# 2            Poolife Bromine Tablets | 25 LBS (62182)
# 3                 Poolife NST Prime Tablets | 4.5 LBS
# 4           Poolife NST Prime Tablets | 9 LBS (22424)
# 5        Poolife NST Prime Tablets | 20.2 LBS (22425)
# 6        Poolife NST Prime Tablets | 39.4 LBS (22426)
# 7        Poolife 3" Cleaning Tablet | 1, 7 OZ (42130)
# 8      Poolife 3" Cleaning Tablets | 4.81 LBS (42107)
# 9                            Sirona Brom Tabs | 82235
# 10      GLB Large 3" Chlorine Tablets | 71228A | 4 LB
# 11     GLB Generation Bromine Tablets | 71443 | 25 LB
# 12                  GLB Triple Tab | 71446A | 22.5 LB
# 13                    GLB Triple Tab | 71445A | 10 LB
# 14      GLB Small 1" Chlorine Tablets | 71239A | 5 LB
# 15     GLB Large 3" Chlorine Tablets | 71236A | 50 LB
# 16     GLB Large 3" Chlorine Tablets | 71234A | 25 LB
# 17  GLB Longevity Cal Hypo Chlorine Tablets | 7143...
# 18  GLB Longevity Cal Hypo Chlorine Tablets | 7143...
# 19  Applied Biochemists Granular Chlorine 50 lb | ...
# 20  Applied Biochemists Oxytrine | 40720 | 50 lb |...
# 21  Applied Biochemists Power Blast 70 | 40710 | 1...
# 22  Applied Biochemists 3" Chlorine Tablets | 4063...
# 23  Leisure Time Bromine Tabs | 45404 | 1" Bromine...
# 24    POOL SEASON Chlorinating Tablets - 50 LB Bucket
# 25    POOL SEASON Chlorinating Tablets - 25 LB Bucket
# 26     POOL SEASON Chlorinating Tablets - 8 LB Bucket
#
#                                              Overview    Price         Stock  \
# 0   steady, consistent chlorination | sanitized, c...  $169.95      In stock
# 1   pool maintenance | 1-inch trichlor tablets | k...   $52.99      In stock
# 2   slow-dissolving tablets | continuous disinfect...  $299.00  Out of stock
# 3   chlorine | oxidizers | stabilizers | residenti...   $41.99  Out of stock
# 4   slow-dissolving tablets | chlorine sanitizers ...   $72.99  Out of stock
# 5   larger pools | chlorine | oxidizing | long-las...  $124.99  Out of stock
# 6   39.4 LBS | dual-action sanitization | oxidatio...  $276.99      In stock
# 7   sanitized and crystal clear | slow-dissolving ...    $6.99      In stock
# 8   sanitized and crystal clear | slow-dissolving ...   $42.99  Out of stock
# 9   effective and continuous sanitization | powerf...   $42.99      In stock
# 10  long-lasting, slow-dissolving | pool sanitizat...   $42.99  Out of stock
# 11  bromine-based pool systems | 25 LB pack | brom...  $326.99  Out of stock
# 12  triple-action formula | long-lasting, efficien...  $165.99  Out of stock
# 13  triple-action formula | long-lasting, efficien...   $94.99  Out of stock
# 14  fast-dissolving | pool sanitization | 5 lb pac...   $53.99  Out of stock
# 15  long-lasting, slow-release | clean, clear, and...  $309.99  Out of stock
# 16  long-lasting, slow-dissolving | consistent poo...  $160.99  Out of stock
# 17  powerful and long-lasting sanitization solutio...    $2.99  Out of stock
# 18  long-lasting pool sanitization | eliminate bac...  $120.99  Out of stock
# 19  fast-dissolving chlorine | pool sanitation | c...  $259.95      In stock
# 20  powerful pool oxidizer | organic contaminants ...  $404.99  Out of stock
# 21  pool shock treatment | clear cloudy water | el...  $437.99  Out of stock
# 22  chlorine tablets | consistent, long-lasting sa...  $315.99  Out of stock
# 23  1" bromine tablets | spa and pool sanitization...   $47.99  Out of stock
# 24                        Features: | Specifications:  $209.00  Out of stock
# 25                        Features: | Specifications:  $139.00  Out of stock
# 26                        Features: | Specifications:   $74.99  Out of stock
#
#                                           Description  \
# 0   Poolife 3" Chlorine Tabs arehighly effective c...
# 1   Poolife 1" Cleaning Tablets arehighly effectiv...
# 2                                       Key Features:
# 3   Poolife NST Prime Tablets are designed forpool...
# 4   Poolife NST Prime Tablets in the9 LBSsize are ...
# 5   Poolife NST Prime Tablets in the20.2 LBSsize a...
# 6   ThePoolife NST Prime Tabletsin the39.4 LBSsize...
# 7   Poolife 3" Cleaning Tablets providelong-lastin...
# 8   Poolife 3" Cleaning Tablets providelong-lastin...
# 9   The NEW Sirona Brom Tabs areslow-dissolving br...
# 10  GLB Large 3" Chlorine Tabletsprovide along-las...
# 11  GLB Generation Bromine Tabletsare designed spe...
# 12  GLB Triple Taboffers atriple-action formulatha...
# 13  GLB Triple Tabcombines the power of atriple-ac...
# 14  GLB Small 1" Chlorine Tabletsoffer an effectiv...
# 15  GLB Large 3" Chlorine Tabletsare designed forl...
# 16  GLB Large 3" Chlorine Tabletsoffer along-lasti...
# 17  GLB Longevity Cal Hypo Chlorine Tabletsoffer a...
# 18  GLB Longevity Cal Hypo Chlorine Tabletsare des...
# 19  Applied Biochemists Granular Chlorine(40697A) ...
# 20  Applied Biochemists Oxytrine(40720) is apowerf...
# 21  Applied Biochemists Power Blast 70(40710) is a...
# 22  Applied Biochemists 3" Chlorine Tablets(40631A...
# 23  The NEW Leisure Time Bromine Tabs(45404) are1"...
# 24  ThePOOL SEASON Chlorinating Tablets (50 LB Buc...
# 25  ThePOOL SEASON Chlorinating Tablets (25 LB Buc...
# 26  ThePOOL SEASON Chlorinating Tablets (8 LB Buck...
#
#                                                  Link Manufacturer SKU  \
# 0   https://www.epoolsupply.com/collections/poolif...            42118
# 1   https://www.epoolsupply.com/collections/poolif...            42104
# 2   https://www.epoolsupply.com/collections/poolif...            62182
# 3   https://www.epoolsupply.com/collections/poolif...            22427
# 4   https://www.epoolsupply.com/collections/poolif...            22424
# 5   https://www.epoolsupply.com/collections/poolif...            22425
# 6   https://www.epoolsupply.com/collections/poolif...            22426
# 7   https://www.epoolsupply.com/collections/poolif...            42130
# 8   https://www.epoolsupply.com/collections/poolif...            42107
# 9   https://www.epoolsupply.com/collections/sirona...            82235
# 10  https://www.epoolsupply.com/collections/glb-ch...           71228A
# 11  https://www.epoolsupply.com/collections/glb-ch...            71443
# 12  https://www.epoolsupply.com/collections/glb-ch...           71446A
# 13  https://www.epoolsupply.com/collections/glb-ch...           71445A
# 14  https://www.epoolsupply.com/collections/glb-ch...           71239A
# 15  https://www.epoolsupply.com/collections/glb-ch...           71236A
# 16  https://www.epoolsupply.com/collections/glb-ch...           71234A
# 17  https://www.epoolsupply.com/collections/glb-ch...            71437
# 18  https://www.epoolsupply.com/collections/glb-ch...            71434
# 19  https://www.epoolsupply.com/collections/applie...           40697A
# 20  https://www.epoolsupply.com/collections/applie...            40720
# 21  https://www.epoolsupply.com/collections/applie...            40710
# 22  https://www.epoolsupply.com/collections/applie...           40631A
# 23  https://www.epoolsupply.com/collections/leisur...            45404
# 24  https://www.epoolsupply.com/collections/pool-s...      HGH-50-3750
# 25  https://www.epoolsupply.com/collections/pool-s...      HGH-50-3725
# 26  https://www.epoolsupply.com/collections/pool-s...      HGH-50-3708
#
#                                  Brand
# 0        Poolife Chlorine & Sanitizers
# 1        Poolife Chlorine & Sanitizers
# 2        Poolife Chlorine & Sanitizers
# 3        Poolife Chlorine & Sanitizers
# 4        Poolife Chlorine & Sanitizers
# 5        Poolife Chlorine & Sanitizers
# 6        Poolife Chlorine & Sanitizers
# 7        Poolife Chlorine & Sanitizers
# 8        Poolife Chlorine & Sanitizers
# 9         Sirona Chlorine & Sanitizers
# 10           GLB Chlorine & Sanitizers
# 11           GLB Chlorine & Sanitizers
# 12           GLB Chlorine & Sanitizers
# 13           GLB Chlorine & Sanitizers
# 14           GLB Chlorine & Sanitizers
# 15           GLB Chlorine & Sanitizers
# 16           GLB Chlorine & Sanitizers
# 17           GLB Chlorine & Sanitizers
# 18           GLB Chlorine & Sanitizers
# 19   Applied Bio Chlorine & Sanitizers
# 20   Applied Bio Chlorine & Sanitizers
# 21   Applied Bio Chlorine & Sanitizers
# 22   Applied Bio Chlorine & Sanitizers
# 23  Leisure Time Chlorine & Sanitizers
# 24   Pool Season Chlorine & Sanitizers
# 25   Pool Season Chlorine & Sanitizers
# 26   Pool Season Chlorine & Sanitizers
